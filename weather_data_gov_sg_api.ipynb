# %% [markdown]
# # explore_data_gov_sg_api
#
# ## Purpose:
# Explore the weather-related APIs at https://developers.data.gov.sg.
#
# ## History:
# - 2018-04-18 - Shi Yuan: Removed API Key requirement since Feb 2018, code changes
# - 2017-05 - Benjamin S. Grandey
# - 2017-05-29 - Moving from atmos-scripts repository to access-data-gov-sg repository, and renaming from data_gov_sg_explore.ipynb to explore_data_gov_sg_api.ipynb.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import requests
import seaborn as sns
from tqdm import tqdm

# %matplotlib inline

# %% [markdown]
# ## Meta-data for available meteorological APIs
# [I added this section after exploring the wind-speed data - see below.]

# %%
# Meteorological variables
for variable in ['rainfall', 'wind-speed', 'wind-direction', 'air-temperature', 'relative-humidity']:
    print(variable)
    r = requests.get('https://api.data.gov.sg/v1/environment/{}'.format(variable))
    metadata = r.json()['metadata']
    for key in metadata.keys():
        if key != 'stations':  # don't print information about stations
            print('  {}: {}'.format(key, r.json()['metadata'][key]))
            
stations_df = pd.DataFrame(r.json()['metadata']['stations'])
stations_df['longitude'] = ''
stations_df['latitude'] = ''

for i in range(0,len(stations_df)):
    stations_df['longitude'][i] = stations_df['location'][i]['longitude']
    stations_df['latitude'][i] = stations_df['location'][i]['latitude']
    
stations_df = stations_df.rename(columns={'id': 'station_id'})
stations_df
# Out:
# rainfall
#   reading_type: TB1 Rainfall 5 Minute Total F
#   reading_unit: mm
# wind-speed
#   reading_type: Wind Speed AVG(S)10M M1M
#   reading_unit: knots
# wind-direction
#   reading_type: Wind Dir AVG (S) 10M M1M
#   reading_unit: degrees
# air-temperature
#   reading_type: DBT 1M F
#   reading_unit: deg C
# relative-humidity
#   reading_type: RH 1M F
#   reading_unit: percentage
#    device_id station_id                                       location  \
# 0       S117       S117      {'latitude': 1.256, 'longitude': 103.679}
# 1       S107       S107    {'latitude': 1.3135, 'longitude': 103.9625}
# 2        S43        S43    {'latitude': 1.3399, 'longitude': 103.8878}
# 3        S44        S44  {'latitude': 1.34583, 'longitude': 103.68166}
# 4       S121       S121  {'latitude': 1.37288, 'longitude': 103.72244}
# 5       S106       S106    {'latitude': 1.4168, 'longitude': 103.9673}
# 6       S111       S111   {'latitude': 1.31055, 'longitude': 103.8365}
# 7        S60        S60      {'latitude': 1.25, 'longitude': 103.8279}
# 8       S115       S115  {'latitude': 1.29377, 'longitude': 103.61843}
# 9        S24        S24    {'latitude': 1.3678, 'longitude': 103.9826}
# 10      S104       S104  {'latitude': 1.44387, 'longitude': 103.78538}
# 11      S100       S100   {'latitude': 1.4172, 'longitude': 103.74855}
#
#                        name longitude latitude
# 0               Banyan Road   103.679    1.256
# 1        East Coast Parkway   103.963   1.3135
# 2            Kim Chuan Road   103.888   1.3399
# 3            Nanyang Avenue   103.682  1.34583
# 4    Old Choa Chu Kang Road   103.722  1.37288
# 5                Pulau Ubin   103.967   1.4168
# 6               Scotts Road   103.837  1.31055
# 7                   Sentosa   103.828     1.25
# 8       Tuas South Avenue 3   103.618  1.29377
# 9   Upper Changi Road North   103.983   1.3678
# 10       Woodlands Avenue 9   103.785  1.44387
# 11           Woodlands Road   103.749   1.4172

# %%
r.json()['metadata']['stations']
# Out:
# [{'device_id': 'S117',
#   'id': 'S117',
#   'location': {'latitude': 1.256, 'longitude': 103.679},
#   'name': 'Banyan Road'},
#  {'device_id': 'S107',
#   'id': 'S107',
#   'location': {'latitude': 1.3135, 'longitude': 103.9625},
#   'name': 'East Coast Parkway'},
#  {'device_id': 'S43',
#   'id': 'S43',
#   'location': {'latitude': 1.3399, 'longitude': 103.8878},
#   'name': 'Kim Chuan Road'},
#  {'device_id': 'S44',
#   'id': 'S44',
#   'location': {'latitude': 1.34583, 'longitude': 103.68166},
#   'name': 'Nanyang Avenue'},
#  {'device_id': 'S121',
#   'id': 'S121',
#   'location': {'latitude': 1.37288, 'longitude': 103.72244},
#   'name': 'Old Choa Chu Kang Road'},
#  {'device_id': 'S106',
#   'id': 'S106',
#   'location': {'latitude': 1.4168, 'longitude': 103.9673},
#   'name': 'Pulau Ubin'},
#  {'device_id': 'S111',
#   'id': 'S111',
#   'location': {'latitude': 1.31055, 'longitude': 103.8365},
#   'name': 'Scotts Road'},
#  {'device_id': 'S60',
#   'id': 'S60',
#   'location': {'latitude': 1.25, 'longitude': 103.8279},
#   'name': 'Sentosa'},
#  {'device_id': 'S115',
#   'id': 'S115',
#   'location': {'latitude': 1.29377, 'longitude': 103.61843},
#   'name': 'Tuas South Avenue 3'},
#  {'device_id': 'S24',
#   'id': 'S24',
#   'location': {'latitude': 1.3678, 'longitude': 103.9826},
#   'name': 'Upper Changi Road North'},
#  {'device_id': 'S104',
#   'id': 'S104',
#   'location': {'latitude': 1.44387, 'longitude': 103.78538},
#   'name': 'Woodlands Avenue 9'},
#  {'device_id': 'S100',
#   'id': 'S100',
#   'location': {'latitude': 1.4172, 'longitude': 103.74855},
#   'name': 'Woodlands Road'}]

# %% [markdown]
# ## Specify Date

# %%
date = '2018-01-08'
datetime = date + ' 00:05:00'
datetime
# Out:
# '2018-01-08 00:05:00'

# %% [markdown]
# ## Wind-speed (5-min interval)
# https://data.gov.sg/dataset/realtime-weather-readings?resource_id=16035f22-37b4-4a5c-b024-ca2381f11b48

# %%
pd.date_range(datetime, periods=(24*12+1), freq='5min')
# Out:
# DatetimeIndex(['2017-12-31 00:05:00', '2017-12-31 00:10:00',
#                '2017-12-31 00:15:00', '2017-12-31 00:20:00',
#                '2017-12-31 00:25:00', '2017-12-31 00:30:00',
#                '2017-12-31 00:35:00', '2017-12-31 00:40:00',
#                '2017-12-31 00:45:00', '2017-12-31 00:50:00',
#                ...
#                '2017-12-31 23:20:00', '2017-12-31 23:25:00',
#                '2017-12-31 23:30:00', '2017-12-31 23:35:00',
#                '2017-12-31 23:40:00', '2017-12-31 23:45:00',
#                '2017-12-31 23:50:00', '2017-12-31 23:55:00',
#                '2018-01-01 00:00:00', '2018-01-01 00:05:00'],
#               dtype='datetime64[ns]', length=289, freq='5T')

# %%
# Get wind-speed at 5-min intervals on a specific date
# Note: if 'date' is used instead of 'date_time', the API appears to timeout
wind_speed_df = pd.DataFrame(columns=['station_id', 'wind-speed', 'timestamp (SGT)'])
for dt in pd.date_range(datetime, periods=(24*12+1), freq='5min'):
    r = requests.get('https://api.data.gov.sg/v1/environment/wind-speed',
                     params={'date_time': dt.strftime('%Y-%m-%dT%H:%M:%S')})
    temp_df = pd.DataFrame(r.json()['items'][0]['readings'])
    temp_df = temp_df.rename(columns={'value': 'wind-speed'})
    temp_df['timestamp (SGT)'] = pd.to_datetime(r.json()['items'][0]['timestamp'].split('+')[0])
    wind_speed_df = wind_speed_df.append(temp_df, ignore_index=True)
#wind_speed_df.head(15)

stations_df = pd.DataFrame(r.json()['metadata']['stations'])
stations_df['longitude'] = ''
stations_df['latitude'] = ''

for i in range(0,len(stations_df)):
    stations_df['longitude'][i] = stations_df['location'][i]['longitude']
    stations_df['latitude'][i] = stations_df['location'][i]['latitude']
    
stations_df = stations_df.rename(columns={'id': 'station_id'})
stations_df
# Out:
#    device_id station_id                                       location  \
# 0       S109       S109    {'latitude': 1.3764, 'longitude': 103.8492}
# 1       S117       S117      {'latitude': 1.256, 'longitude': 103.679}
# 2        S50        S50    {'latitude': 1.3337, 'longitude': 103.7768}
# 3       S107       S107    {'latitude': 1.3135, 'longitude': 103.9625}
# 4        S43        S43    {'latitude': 1.3399, 'longitude': 103.8878}
# 5       S106       S106    {'latitude': 1.4168, 'longitude': 103.9673}
# 6       S102       S102      {'latitude': 1.189, 'longitude': 103.768}
# 7       S122       S122   {'latitude': 1.41731, 'longitude': 103.8249}
# 8       S115       S115  {'latitude': 1.29377, 'longitude': 103.61843}
# 9        S24        S24    {'latitude': 1.3678, 'longitude': 103.9826}
# 10      S116       S116      {'latitude': 1.281, 'longitude': 103.754}
# 11      S104       S104  {'latitude': 1.44387, 'longitude': 103.78538}
# 12      S100       S100   {'latitude': 1.4172, 'longitude': 103.74855}
#
#                        name longitude latitude
# 0       Ang Mo Kio Avenue 5   103.849   1.3764
# 1               Banyan Road   103.679    1.256
# 2             Clementi Road   103.777   1.3337
# 3        East Coast Parkway   103.963   1.3135
# 4            Kim Chuan Road   103.888   1.3399
# 5                Pulau Ubin   103.967   1.4168
# 6          Semakau Landfill   103.768    1.189
# 7            Sembawang Road   103.825  1.41731
# 8       Tuas South Avenue 3   103.618  1.29377
# 9   Upper Changi Road North   103.983   1.3678
# 10       West Coast Highway   103.754    1.281
# 11       Woodlands Avenue 9   103.785  1.44387
# 12           Woodlands Road   103.749   1.4172

# %%
# Union of wind-speed and station data
outer_df = pd.merge(wind_speed_df, stations_df, how='outer', on=['station_id'])
outer_df.head(15)

# drop duplicating info columns
outer_wind_speed_df = outer_df.drop(['location','device_id'], axis=1)
outer_wind_speed_df.head(15)
# Out:
#    station_id  wind-speed     timestamp (SGT)                 name longitude  \
# 0        S109         5.3 2017-05-24 00:00:00  Ang Mo Kio Avenue 5   103.849
# 1        S109         4.1 2017-05-24 00:05:00  Ang Mo Kio Avenue 5   103.849
# 2        S109         4.7 2017-05-24 00:10:00  Ang Mo Kio Avenue 5   103.849
# 3        S109         6.0 2017-05-24 00:15:00  Ang Mo Kio Avenue 5   103.849
# 4        S109         9.3 2017-05-24 00:20:00  Ang Mo Kio Avenue 5   103.849
# 5        S109         6.4 2017-05-24 00:25:00  Ang Mo Kio Avenue 5   103.849
# 6        S109         2.9 2017-05-24 00:30:00  Ang Mo Kio Avenue 5   103.849
# 7        S109         4.7 2017-05-24 00:35:00  Ang Mo Kio Avenue 5   103.849
# 8        S109         3.1 2017-05-24 00:40:00  Ang Mo Kio Avenue 5   103.849
# 9        S109         7.2 2017-05-24 00:45:00  Ang Mo Kio Avenue 5   103.849
# 10       S109        10.7 2017-05-24 00:50:00  Ang Mo Kio Avenue 5   103.849
# 11       S109         5.8 2017-05-24 00:55:00  Ang Mo Kio Avenue 5   103.849
# 12       S109         4.5 2017-05-24 01:00:00  Ang Mo Kio Avenue 5   103.849
# 13       S109         7.2 2017-05-24 01:05:00  Ang Mo Kio Avenue 5   103.849
# 14       S109         7.4 2017-05-24 01:10:00  Ang Mo Kio Avenue 5   103.849
#
#    latitude
# 0    1.3764
# 1    1.3764
# 2    1.3764
# 3    1.3764
# 4    1.3764
# 5    1.3764
# 6    1.3764
# 7    1.3764
# 8    1.3764
# 9    1.3764
# 10   1.3764
# 11   1.3764
# 12   1.3764
# 13   1.3764
# 14   1.3764

# %%
filename = 'wind_speed_{}.csv'.format(date)
filename

outer_wind_speed_df.to_csv(filename, index = False)

# %%
# export to csv
#outer_df.to_csv('output.csv', index = False)

# %%
#outer_df.info()

# %%
#outer_df.groupby('name').describe()

# %%
#wind_speed_df.info()

# %%
#wind_speed_df.groupby('station_id').describe()

# %% [markdown]
# ## Rainfall

# %%
# Get rainfall at 5-min intervals on a specific date
rainfall_df = pd.DataFrame(columns=['station_id', 'rainfall', 'timestamp (SGT)'])
for dt in tqdm(pd.date_range(datetime, periods=(24*12+1), freq='5min')):  # I remember this was a wet day
    r = requests.get('https://api.data.gov.sg/v1/environment/rainfall',
                     params={'date_time': dt.strftime('%Y-%m-%dT%H:%M:%S')})
    try:
        temp_df = pd.DataFrame(r.json()['items'][0]['readings'])
    except ValueError:
        print('No data JSONDecodeError {}'.format(dt))
        continue
    except KeyError:
        print('No items KeyError {}'.format(dt))
        continue
    temp_df = temp_df.rename(columns={'value': 'rainfall'})
    temp_df['timestamp (SGT)'] = pd.to_datetime(r.json()['items'][0]['timestamp'].split('+')[0])
    rainfall_df = rainfall_df.append(temp_df, ignore_index=True)
#rainfall_df.head()

stations_df = pd.DataFrame(r.json()['metadata']['stations'])
stations_df['longitude'] = ''
stations_df['latitude'] = ''

for i in range(0,len(stations_df)):
    stations_df['longitude'][i] = stations_df['location'][i]['longitude']
    stations_df['latitude'][i] = stations_df['location'][i]['latitude']
    
stations_df = stations_df.rename(columns={'id': 'station_id'})
stations_df
# Out:
# 100%|██████████| 289/289 [00:58<00:00,  4.97it/s]
#    device_id station_id                                       location  \
# 0        S77        S77    {'latitude': 1.2937, 'longitude': 103.8125}
# 1       S109       S109    {'latitude': 1.3764, 'longitude': 103.8492}
# 2       S117       S117      {'latitude': 1.256, 'longitude': 103.679}
# 3        S55        S55     {'latitude': 1.3837, 'longitude': 103.886}
# 4        S64        S64    {'latitude': 1.3824, 'longitude': 103.7603}
# 5        S90        S90    {'latitude': 1.3191, 'longitude': 103.8191}
# 6        S61        S61     {'latitude': 1.323, 'longitude': 103.9217}
# 7       S114       S114        {'latitude': 1.38, 'longitude': 103.73}
# 8        S11        S11    {'latitude': 1.3746, 'longitude': 103.6938}
# 9        S50        S50    {'latitude': 1.3337, 'longitude': 103.7768}
# 10      S101       S101   {'latitude': 1.35053, 'longitude': 103.7134}
# 11      S118       S118    {'latitude': 1.2994, 'longitude': 103.8461}
# 12      S120       S120    {'latitude': 1.30874, 'longitude': 103.818}
# 13       S33        S33      {'latitude': 1.3081, 'longitude': 103.71}
# 14       S71        S71    {'latitude': 1.2923, 'longitude': 103.7815}
# 15       S43        S43    {'latitude': 1.3399, 'longitude': 103.8878}
# 16       S66        S66    {'latitude': 1.4387, 'longitude': 103.7363}
# 17      S112       S112  {'latitude': 1.43854, 'longitude': 103.70131}
# 18       S07        S07    {'latitude': 1.3415, 'longitude': 103.8334}
# 19       S40        S40   {'latitude': 1.4044, 'longitude': 103.78962}
# 20      S108       S108    {'latitude': 1.2799, 'longitude': 103.8703}
# 21      S113       S113   {'latitude': 1.30648, 'longitude': 103.9104}
# 22       S44        S44  {'latitude': 1.34583, 'longitude': 103.68166}
# 23      S119       S119   {'latitude': 1.30105, 'longitude': 103.8666}
# 24      S121       S121  {'latitude': 1.37288, 'longitude': 103.72244}
# 25       S35        S35    {'latitude': 1.3329, 'longitude': 103.7556}
# 26       S29        S29      {'latitude': 1.387, 'longitude': 103.935}
# 27       S94        S94    {'latitude': 1.3662, 'longitude': 103.9528}
# 28       S78        S78  {'latitude': 1.30703, 'longitude': 103.89067}
# 29      S106       S106    {'latitude': 1.4168, 'longitude': 103.9673}
# 30       S81        S81    {'latitude': 1.4029, 'longitude': 103.9092}
# 31      S111       S111   {'latitude': 1.31055, 'longitude': 103.8365}
# 32      S900       S900  {'latitude': 1.41284, 'longitude': 103.86922}
# 33      S102       S102      {'latitude': 1.189, 'longitude': 103.768}
# 34      S122       S122   {'latitude': 1.41731, 'longitude': 103.8249}
# 35       S60        S60      {'latitude': 1.25, 'longitude': 103.8279}
# 36       S46        S46    {'latitude': 1.3416, 'longitude': 103.8106}
# 37       S84        S84    {'latitude': 1.3437, 'longitude': 103.9444}
# 38       S79        S79    {'latitude': 1.3004, 'longitude': 103.8372}
# 39       S92        S92    {'latitude': 1.2841, 'longitude': 103.7886}
# 40       S88        S88    {'latitude': 1.3427, 'longitude': 103.8482}
# 41      S123       S123    {'latitude': 1.3214, 'longitude': 103.8577}
# 42       S89        S89  {'latitude': 1.31985, 'longitude': 103.66162}
# 43      S115       S115  {'latitude': 1.29377, 'longitude': 103.61843}
# 44       S82        S82    {'latitude': 1.3247, 'longitude': 103.6351}
# 45       S24        S24    {'latitude': 1.3678, 'longitude': 103.9826}
# 46       S69        S69       {'latitude': 1.37, 'longitude': 103.805}
# 47       S36        S36    {'latitude': 1.3382, 'longitude': 103.8657}
# 48       S08        S08    {'latitude': 1.3701, 'longitude': 103.8271}
# 49      S116       S116      {'latitude': 1.281, 'longitude': 103.754}
# 50      S104       S104  {'latitude': 1.44387, 'longitude': 103.78538}
# 51       S91        S91    {'latitude': 1.4301, 'longitude': 103.8308}
#
#                            name longitude latitude
# 0                Alexandra Road   103.812   1.2937
# 1           Ang Mo Kio Avenue 5   103.849   1.3764
# 2                   Banyan Road   103.679    1.256
# 3                Buangkok Green   103.886   1.3837
# 4            Bukit Panjang Road    103.76   1.3824
# 5              Bukit Timah Road   103.819   1.3191
# 6              Chai Chee Street   103.922    1.323
# 7        Choa Chu Kang Avenue 4    103.73     1.38
# 8            Choa Chu Kang Road   103.694   1.3746
# 9                 Clementi Road   103.777   1.3337
# 10             Corporation Road   103.713  1.35053
# 11                   Handy Road   103.846   1.2994
# 12                 Holland Road   103.818  1.30874
# 13             Jurong Pier Road    103.71   1.3081
# 14              Kent Ridge Road   103.781   1.2923
# 15               Kim Chuan Road   103.888   1.3399
# 16                   Kranji Way   103.736   1.4387
# 17            Lim Chu Kang Road   103.701  1.43854
# 18                  Lornie Road   103.833   1.3415
# 19             Mandai Lake Road    103.79   1.4044
# 20         Marina Gardens Drive    103.87   1.2799
# 21           Marine Parade Road    103.91  1.30648
# 22               Nanyang Avenue   103.682  1.34583
# 23               Nicoll Highway   103.867  1.30105
# 24       Old Choa Chu Kang Road   103.722  1.37288
# 25            Old Toh Tuck Road   103.756   1.3329
# 26           Pasir Ris Drive 12   103.935    1.387
# 27          Pasir Ris Street 51   103.953   1.3662
# 28                   Poole Road   103.891  1.30703
# 29                   Pulau Ubin   103.967   1.4168
# 30              Punggol Central   103.909   1.4029
# 31                  Scotts Road   103.837  1.31055
# 32       Seletar Aerospace View   103.869  1.41284
# 33             Semakau Landfill   103.768    1.189
# 34               Sembawang Road   103.825  1.41731
# 35                      Sentosa   103.828     1.25
# 36                    Sime Road   103.811   1.3416
# 37                 Simei Avenue   103.944   1.3437
# 38                Somerset Road   103.837   1.3004
# 39       South Buona Vista Road   103.789   1.2841
# 40              Toa Payoh North   103.848   1.3427
# 41                  Towner Road   103.858   1.3214
# 42                    Tuas Road   103.662  1.31985
# 43          Tuas South Avenue 3   103.618  1.29377
# 44               Tuas West Road   103.635   1.3247
# 45      Upper Changi Road North   103.983   1.3678
# 46  Upper Peirce Reservoir Park   103.805     1.37
# 47         Upper Serangoon Road   103.866   1.3382
# 48           Upper Thomson Road   103.827   1.3701
# 49           West Coast Highway   103.754    1.281
# 50           Woodlands Avenue 9   103.785  1.44387
# 51              Yishun Avenue 5   103.831   1.4301

# %%
# Get rainfall at 30-min intervals on a specific date
rainfall_df = pd.DataFrame(columns=['station_id', 'rainfall', 'timestamp (SGT)'])
for dt in tqdm(pd.date_range(datetime, periods=(24*(60/30)+1), freq='30min')):  # I remember this was a wet day
    r = requests.get('https://api.data.gov.sg/v1/environment/rainfall',
                     params={'date_time': dt.strftime('%Y-%m-%dT%H:%M:%S')})
    try:
        temp_df = pd.DataFrame(r.json()['items'][0]['readings'])
    except ValueError:
        print('No data JSONDecodeError {}'.format(dt))
        continue
    except KeyError:
        print('No items KeyError {}'.format(dt))
        continue
    temp_df = temp_df.rename(columns={'value': 'rainfall'})
    temp_df['timestamp (SGT)'] = pd.to_datetime(r.json()['items'][0]['timestamp'].split('+')[0])
    rainfall_df = rainfall_df.append(temp_df, ignore_index=True)
#rainfall_df.head()

stations_df = pd.DataFrame(r.json()['metadata']['stations'])
stations_df['longitude'] = ''
stations_df['latitude'] = ''

#for i in range(0,len(stations_df)):
#    stations_df['longitude'][i] = stations_df['location'][i]['longitude']
#    stations_df['latitude'][i] = stations_df['location'][i]['latitude']
    
#stations_df = stations_df.rename(columns={'id': 'station_id'})
#stations_df
# Out:
# 100%|██████████| 49/49 [00:11<00:00,  4.18it/s]

# %%
stations_df = pd.read_csv("stations.csv")
stations_df
# Out:
#    station_id                      name  latitude  longitude
# 0          S7     Macritchie Reservoir     1.3417   103.8338
# 1          S8   Lower Peirce Reservoir     1.3701   103.8271
# 2         S11     Choa Chu Kang (West)     1.3746   103.6938
# 3         S24   Changi Climate Station     1.3678   103.9826
# 4         S29         Pasir Ris (West)     1.3863   103.9412
# 5         S31            Kampong Bahru     1.2745   103.8280
# 6         S33              Jurong Pier     1.3081   103.7100
# 7         S35               Ulu Pandan     1.3329   103.7556
# 8         S36                Serangoon     1.3382   103.8657
# 9         S40                   Mandai     1.4036   103.7898
# 10        S43                 Tai Seng     1.3399   103.8878
# 11        S44            Jurong (West)     1.3455   103.6806
# 12        S46            Upper Thomson     1.3416   103.8106
# 13        S50                 Clementi     1.3337   103.7768
# 14        S55                 Buangkok     1.3837   103.8860
# 15        S60           Sentosa Island     1.2500   103.8279
# 16        S61                Chai Chee     1.3277   103.9203
# 17        S63          Boon Lay (West)     1.3275   103.7042
# 18        S64            Bukit Panjang     1.3824   103.7603
# 19        S66         Kranji Reservoir     1.4387   103.7363
# 20        S69   Upper Peirce Reservoir     1.3700   103.8050
# 21        S71               Kent Ridge     1.2923   103.7815
# 22        S77               Queenstown     1.2937   103.8125
# 23        S78           Tanjong Katong     1.3070   103.8907
# 24        S79          Somerset (Road)     1.3004   103.8372
# 25        S81                  Punggol     1.4029   103.9092
# 26        S82                Tuas West     1.3247   103.6351
# 27        S84                    Simei     1.3437   103.9444
# 28        S86          Boon Lay (East)     1.3302   103.7205
# 29        S88                Toa Payoh     1.3415   103.8519
# 30        S89                     Tuas     1.3199   103.6616
# 31        S90              Bukit Timah     1.3191   103.8191
# 32        S91                   Yishun     1.4301   103.8308
# 33        S92              Buona Vista     1.2841   103.7886
# 34        S94      Pasir Ris (Central)     1.3679   103.9489
# 35       S101           Jurong (North)     1.3505   103.7134
# 36       S102           Semakau Island     1.1890   103.7680
# 37       S104                Admiralty     1.4439   103.7854
# 38       S105           Admiralty West     1.4582   103.7953
# 39       S106               Pulau Ubin     1.4168   103.9673
# 40       S107       East Coast Parkway     1.3134   103.9619
# 41       S108           Marina Barrage     1.2799   103.8703
# 42       S109               Ang Mo Kio     1.3764   103.8492
# 43       S110          Serangoon North     1.3606   103.8697
# 44       S111                   Newton     1.3106   103.8365
# 45       S112             Lim Chu Kang     1.4385   103.7013
# 46       S113            Marine Parade     1.3065   103.9107
# 47       S114  Choa Chu Kang (Central)     1.3819   103.7386
# 48       S115               Tuas South     1.2938   103.6184
# 49       S116            Pasir Panjang     1.2810   103.7540
# 50       S117            Jurong Island     1.2542   103.6741
# 51       S118              Dhoby Ghaut     1.2994   103.8461
# 52       S119           Nicoll Highway     1.3011   103.8666
# 53       S120           Botanic Garden     1.3087   103.8180
# 54       S121    Choa Chu Kang (South)     1.3729   103.7224
# 55       S122                   Khatib     1.4173   103.8249
# 56       S123                  Whampoa     1.3214   103.8577

# %%
rainfall_df['rainfall'] = rainfall_df['rainfall'].astype('float')  # convert to float

# Union of wind-speed and station data
outer_df = pd.merge(rainfall_df, stations_df, how='outer', on=['station_id'])
outer_df.head(15)
# Out:
#    station_id  rainfall     timestamp (SGT)         name  latitude  longitude
# 0         S77       0.0 2018-01-08 00:05:00  Queenstown     1.2937   103.8125
# 1         S77       0.0 2018-01-08 00:35:00  Queenstown     1.2937   103.8125
# 2         S77       0.0 2018-01-08 01:05:00  Queenstown     1.2937   103.8125
# 3         S77       0.0 2018-01-08 01:35:00  Queenstown     1.2937   103.8125
# 4         S77       0.0 2018-01-08 02:05:00  Queenstown     1.2937   103.8125
# 5         S77       0.0 2018-01-08 02:35:00  Queenstown     1.2937   103.8125
# 6         S77       0.0 2018-01-08 03:05:00  Queenstown     1.2937   103.8125
# 7         S77       0.0 2018-01-08 03:35:00  Queenstown     1.2937   103.8125
# 8         S77       0.0 2018-01-08 04:05:00  Queenstown     1.2937   103.8125
# 9         S77       0.0 2018-01-08 04:25:00  Queenstown     1.2937   103.8125
# 10        S77       0.0 2018-01-08 05:05:00  Queenstown     1.2937   103.8125
# 11        S77       0.0 2018-01-08 05:35:00  Queenstown     1.2937   103.8125
# 12        S77       0.0 2018-01-08 06:05:00  Queenstown     1.2937   103.8125
# 13        S77       0.0 2018-01-08 06:35:00  Queenstown     1.2937   103.8125
# 14        S77       2.0 2018-01-08 07:05:00  Queenstown     1.2937   103.8125

# %%
#pd.to_datetime(r.json()['items'][0]['timestamp'].split('+')[0])

# %%
rainfall_df['rainfall'] = rainfall_df['rainfall'].astype('float')  # convert to float

# Union of wind-speed and station data
outer_df = pd.merge(rainfall_df, stations_df, how='outer', on=['station_id'])
outer_df.head(15)

# drop duplicating info columns
outer_rainfall_df = outer_df.drop(['location','device_id'], axis=1)
outer_rainfall_df.head(15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-e6672d9114fb> in <module>()
#       6
#       7 # drop duplicating info columns
# ----> 8 outer_rainfall_df = outer_df.drop(['location','device_id'], axis=1)
#       9 outer_rainfall_df.head(15)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
#    3626         return self.delete(indexer)
#
# ValueError: labels ['location' 'device_id'] not contained in axis

# %%
outer_rainfall_df.describe()
# Out:
#            rainfall
# count  14786.000000
# mean       0.046612
# std        0.456185
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       11.400000

# %%
#rainfall_df.info()

# %%
#rainfall_df['rainfall'] = rainfall_df['rainfall'].astype('float')  # convert to float
#rainfall_df.info()

# %%
filename = 'rainfall_{}.csv'.format(date)
filename

#outer_rainfall_df.to_csv(filename, index = False)
outer_df.to_csv(filename, index = False)

# %% [markdown]
# ## Temperature

# %%
# Get temperature at 5-min intervals on a specific date
temperature_df = pd.DataFrame(columns=['station_id', 'air-temperature', 'timestamp (SGT)'])
for dt in pd.date_range(datetime, periods=(24*12+1), freq='5min'):  # I remember this was a wet day
    r = requests.get('https://api.data.gov.sg/v1/environment/air-temperature',
                     params={'date_time': dt.strftime('%Y-%m-%dT%H:%M:%S')})
    temp_df = pd.DataFrame(r.json()['items'][0]['readings'])
    temp_df = temp_df.rename(columns={'value': 'air-temperature'})
    temp_df['timestamp (SGT)'] = pd.to_datetime(r.json()['items'][0]['timestamp'].split('+')[0])
    temperature_df = temperature_df.append(temp_df, ignore_index=True)
#temperature_df.head()

stations_df = pd.DataFrame(r.json()['metadata']['stations'])
stations_df['longitude'] = ''
stations_df['latitude'] = ''

for i in range(0,len(stations_df)):
    stations_df['longitude'][i] = stations_df['location'][i]['longitude']
    stations_df['latitude'][i] = stations_df['location'][i]['latitude']
    
stations_df = stations_df.rename(columns={'id': 'station_id'})
stations_df
# Out:
#    device_id station_id                                       location  \
# 0       S109       S109    {'latitude': 1.3764, 'longitude': 103.8492}
# 1       S117       S117      {'latitude': 1.256, 'longitude': 103.679}
# 2        S50        S50    {'latitude': 1.3337, 'longitude': 103.7768}
# 3       S107       S107    {'latitude': 1.3135, 'longitude': 103.9625}
# 4        S43        S43    {'latitude': 1.3399, 'longitude': 103.8878}
# 5       S108       S108    {'latitude': 1.2799, 'longitude': 103.8703}
# 6       S121       S121  {'latitude': 1.37288, 'longitude': 103.72244}
# 7       S106       S106    {'latitude': 1.4168, 'longitude': 103.9673}
# 8       S102       S102      {'latitude': 1.189, 'longitude': 103.768}
# 9       S122       S122   {'latitude': 1.41731, 'longitude': 103.8249}
# 10      S115       S115  {'latitude': 1.29377, 'longitude': 103.61843}
# 11       S24        S24    {'latitude': 1.3678, 'longitude': 103.9826}
# 12      S116       S116      {'latitude': 1.281, 'longitude': 103.754}
# 13      S104       S104  {'latitude': 1.44387, 'longitude': 103.78538}
# 14      S100       S100   {'latitude': 1.4172, 'longitude': 103.74855}
#
#                        name longitude latitude
# 0       Ang Mo Kio Avenue 5   103.849   1.3764
# 1               Banyan Road   103.679    1.256
# 2             Clementi Road   103.777   1.3337
# 3        East Coast Parkway   103.963   1.3135
# 4            Kim Chuan Road   103.888   1.3399
# 5      Marina Gardens Drive    103.87   1.2799
# 6    Old Choa Chu Kang Road   103.722  1.37288
# 7                Pulau Ubin   103.967   1.4168
# 8          Semakau Landfill   103.768    1.189
# 9            Sembawang Road   103.825  1.41731
# 10      Tuas South Avenue 3   103.618  1.29377
# 11  Upper Changi Road North   103.983   1.3678
# 12       West Coast Highway   103.754    1.281
# 13       Woodlands Avenue 9   103.785  1.44387
# 14           Woodlands Road   103.749   1.4172

# %%
# Union of wind-speed and station data
outer_df = pd.merge(temperature_df, stations_df, how='outer', on=['station_id'])
outer_df.head(15)

# drop duplicating info columns
outer_temperature_df = outer_df.drop(['location','device_id'], axis=1)
outer_temperature_df.head(15)
# Out:
#    station_id  air-temperature     timestamp (SGT)                 name  \
# 0        S109             29.3 2017-05-24 00:00:00  Ang Mo Kio Avenue 5
# 1        S109             29.3 2017-05-24 00:05:00  Ang Mo Kio Avenue 5
# 2        S109             29.3 2017-05-24 00:10:00  Ang Mo Kio Avenue 5
# 3        S109             29.3 2017-05-24 00:15:00  Ang Mo Kio Avenue 5
# 4        S109             29.3 2017-05-24 00:20:00  Ang Mo Kio Avenue 5
# 5        S109             29.3 2017-05-24 00:25:00  Ang Mo Kio Avenue 5
# 6        S109             29.3 2017-05-24 00:30:00  Ang Mo Kio Avenue 5
# 7        S109             29.3 2017-05-24 00:35:00  Ang Mo Kio Avenue 5
# 8        S109             29.3 2017-05-24 00:40:00  Ang Mo Kio Avenue 5
# 9        S109             29.3 2017-05-24 00:45:00  Ang Mo Kio Avenue 5
# 10       S109             29.3 2017-05-24 00:50:00  Ang Mo Kio Avenue 5
# 11       S109             29.3 2017-05-24 00:55:00  Ang Mo Kio Avenue 5
# 12       S109             29.2 2017-05-24 01:00:00  Ang Mo Kio Avenue 5
# 13       S109             29.3 2017-05-24 01:05:00  Ang Mo Kio Avenue 5
# 14       S109             29.2 2017-05-24 01:10:00  Ang Mo Kio Avenue 5
#
#    longitude latitude
# 0    103.849   1.3764
# 1    103.849   1.3764
# 2    103.849   1.3764
# 3    103.849   1.3764
# 4    103.849   1.3764
# 5    103.849   1.3764
# 6    103.849   1.3764
# 7    103.849   1.3764
# 8    103.849   1.3764
# 9    103.849   1.3764
# 10   103.849   1.3764
# 11   103.849   1.3764
# 12   103.849   1.3764
# 13   103.849   1.3764
# 14   103.849   1.3764

# %%
filename = 'temperature_{}.csv'.format(date)
filename

outer_temperature_df.to_csv(filename, index = False)

# %%
#r.json()['items'][0]

# %% [markdown]
# ## Relative Humidity

# %%
# Get relative humidity at 5-min intervals on a specific date
humidity_df = pd.DataFrame(columns=['station_id', 'relative-humidity', 'timestamp (SGT)'])
for dt in pd.date_range(datetime, periods=(24*12+1), freq='5min'):  # I remember this was a wet day
    r = requests.get('https://api.data.gov.sg/v1/environment/relative-humidity',
                     params={'date_time': dt.strftime('%Y-%m-%dT%H:%M:%S')})
    temp_df = pd.DataFrame(r.json()['items'][0]['readings'])
    temp_df = temp_df.rename(columns={'value': 'relative-humidity'})
    temp_df['timestamp (SGT)'] = pd.to_datetime(r.json()['items'][0]['timestamp'].split('+')[0])
    humidity_df = humidity_df.append(temp_df, ignore_index=True)
#humidity_df.head()

stations_df = pd.DataFrame(r.json()['metadata']['stations'])
stations_df['longitude'] = ''
stations_df['latitude'] = ''

for i in range(0,len(stations_df)):
    stations_df['longitude'][i] = stations_df['location'][i]['longitude']
    stations_df['latitude'][i] = stations_df['location'][i]['latitude']
    
stations_df = stations_df.rename(columns={'id': 'station_id'})
stations_df
# Out:
#    device_id station_id                                       location  \
# 0       S109       S109    {'latitude': 1.3764, 'longitude': 103.8492}
# 1       S117       S117      {'latitude': 1.256, 'longitude': 103.679}
# 2        S50        S50    {'latitude': 1.3337, 'longitude': 103.7768}
# 3       S107       S107    {'latitude': 1.3135, 'longitude': 103.9625}
# 4        S43        S43    {'latitude': 1.3399, 'longitude': 103.8878}
# 5       S108       S108    {'latitude': 1.2799, 'longitude': 103.8703}
# 6       S121       S121  {'latitude': 1.37288, 'longitude': 103.72244}
# 7       S102       S102      {'latitude': 1.189, 'longitude': 103.768}
# 8       S115       S115  {'latitude': 1.29377, 'longitude': 103.61843}
# 9        S24        S24    {'latitude': 1.3678, 'longitude': 103.9826}
# 10      S116       S116      {'latitude': 1.281, 'longitude': 103.754}
# 11      S104       S104  {'latitude': 1.44387, 'longitude': 103.78538}
# 12      S100       S100   {'latitude': 1.4172, 'longitude': 103.74855}
#
#                        name longitude latitude
# 0       Ang Mo Kio Avenue 5   103.849   1.3764
# 1               Banyan Road   103.679    1.256
# 2             Clementi Road   103.777   1.3337
# 3        East Coast Parkway   103.963   1.3135
# 4            Kim Chuan Road   103.888   1.3399
# 5      Marina Gardens Drive    103.87   1.2799
# 6    Old Choa Chu Kang Road   103.722  1.37288
# 7          Semakau Landfill   103.768    1.189
# 8       Tuas South Avenue 3   103.618  1.29377
# 9   Upper Changi Road North   103.983   1.3678
# 10       West Coast Highway   103.754    1.281
# 11       Woodlands Avenue 9   103.785  1.44387
# 12           Woodlands Road   103.749   1.4172

# %%
# Union of wind-speed and station data
outer_df = pd.merge(humidity_df, stations_df, how='outer', on=['station_id'])
outer_df.head(15)

# drop duplicating info columns
outer_humidity_df = outer_df.drop(['location','device_id'], axis=1)
outer_humidity_df.head(15)
# Out:
#    station_id  relative-humidity     timestamp (SGT)                 name  \
# 0        S109               78.0 2017-05-24 00:00:00  Ang Mo Kio Avenue 5
# 1        S109               78.2 2017-05-24 00:05:00  Ang Mo Kio Avenue 5
# 2        S109               77.7 2017-05-24 00:10:00  Ang Mo Kio Avenue 5
# 3        S109               78.1 2017-05-24 00:15:00  Ang Mo Kio Avenue 5
# 4        S109               78.2 2017-05-24 00:20:00  Ang Mo Kio Avenue 5
# 5        S109               78.3 2017-05-24 00:25:00  Ang Mo Kio Avenue 5
# 6        S109               78.3 2017-05-24 00:30:00  Ang Mo Kio Avenue 5
# 7        S109               78.4 2017-05-24 00:35:00  Ang Mo Kio Avenue 5
# 8        S109               78.7 2017-05-24 00:40:00  Ang Mo Kio Avenue 5
# 9        S109               78.7 2017-05-24 00:45:00  Ang Mo Kio Avenue 5
# 10       S109               78.9 2017-05-24 00:50:00  Ang Mo Kio Avenue 5
# 11       S109               79.2 2017-05-24 00:55:00  Ang Mo Kio Avenue 5
# 12       S109               79.4 2017-05-24 01:00:00  Ang Mo Kio Avenue 5
# 13       S109               79.5 2017-05-24 01:05:00  Ang Mo Kio Avenue 5
# 14       S109               79.6 2017-05-24 01:10:00  Ang Mo Kio Avenue 5
#
#    longitude latitude
# 0    103.849   1.3764
# 1    103.849   1.3764
# 2    103.849   1.3764
# 3    103.849   1.3764
# 4    103.849   1.3764
# 5    103.849   1.3764
# 6    103.849   1.3764
# 7    103.849   1.3764
# 8    103.849   1.3764
# 9    103.849   1.3764
# 10   103.849   1.3764
# 11   103.849   1.3764
# 12   103.849   1.3764
# 13   103.849   1.3764
# 14   103.849   1.3764

# %%
filename = 'humidity_{}.csv'.format(date)
filename

outer_humidity_df.to_csv(filename, index = False)

# %% [markdown]
# ## Merge wind-speed, rainfall, temperature & humidity DataFrames

# %%
outer_df = ""
# Union of data
outer_df = pd.merge(outer_wind_speed_df, outer_rainfall_df, how='outer', on=['station_id', 'timestamp (SGT)', 'name', 'longitude', 'latitude'])
outer_df = pd.merge(outer_df, outer_temperature_df, how='outer', on=['station_id', 'timestamp (SGT)'])
outer_df = pd.merge(outer_df, outer_humidity_df, how='outer', on=['station_id', 'timestamp (SGT)'])

# drop duplicating info columns
outer_df = outer_df.filter(['timestamp (SGT)','station_id', 'name','longitude','latitude','wind-speed','rainfall','air-temperature','relative-humidity'], axis=1)

outer_df
# Out:
#           timestamp (SGT) station_id                    name longitude  \
# 0     2017-05-24 00:00:00       S109     Ang Mo Kio Avenue 5   103.849
# 1     2017-05-24 00:05:00       S109     Ang Mo Kio Avenue 5   103.849
# 2     2017-05-24 00:10:00       S109     Ang Mo Kio Avenue 5   103.849
# 3     2017-05-24 00:15:00       S109     Ang Mo Kio Avenue 5   103.849
# 4     2017-05-24 00:15:00       S109     Ang Mo Kio Avenue 5   103.849
# 5     2017-05-24 00:20:00       S109     Ang Mo Kio Avenue 5   103.849
# 6     2017-05-24 00:20:00       S109     Ang Mo Kio Avenue 5   103.849
# 7     2017-05-24 00:25:00       S109     Ang Mo Kio Avenue 5   103.849
# 8     2017-05-24 00:25:00       S109     Ang Mo Kio Avenue 5   103.849
# 9     2017-05-24 00:30:00       S109     Ang Mo Kio Avenue 5   103.849
# 10    2017-05-24 00:30:00       S109     Ang Mo Kio Avenue 5   103.849
# 11    2017-05-24 00:35:00       S109     Ang Mo Kio Avenue 5   103.849
# 12    2017-05-24 00:35:00       S109     Ang Mo Kio Avenue 5   103.849
# 13    2017-05-24 00:40:00       S109     Ang Mo Kio Avenue 5   103.849
# 14    2017-05-24 00:40:00       S109     Ang Mo Kio Avenue 5   103.849
# 15    2017-05-24 00:45:00       S109     Ang Mo Kio Avenue 5   103.849
# 16    2017-05-24 00:45:00       S109     Ang Mo Kio Avenue 5   103.849
# 17    2017-05-24 00:50:00       S109     Ang Mo Kio Avenue 5   103.849
# 18    2017-05-24 00:50:00       S109     Ang Mo Kio Avenue 5   103.849
# 19    2017-05-24 00:55:00       S109     Ang Mo Kio Avenue 5   103.849
# 20    2017-05-24 01:00:00       S109     Ang Mo Kio Avenue 5   103.849
# 21    2017-05-24 01:05:00       S109     Ang Mo Kio Avenue 5   103.849
# 22    2017-05-24 01:10:00       S109     Ang Mo Kio Avenue 5   103.849
# 23    2017-05-24 01:15:00       S109     Ang Mo Kio Avenue 5   103.849
# 24    2017-05-24 01:15:00       S109     Ang Mo Kio Avenue 5   103.849
# 25    2017-05-24 01:20:00       S109     Ang Mo Kio Avenue 5   103.849
# 26    2017-05-24 01:20:00       S109     Ang Mo Kio Avenue 5   103.849
# 27    2017-05-24 01:25:00       S109     Ang Mo Kio Avenue 5   103.849
# 28    2017-05-24 01:25:00       S109     Ang Mo Kio Avenue 5   103.849
# 29    2017-05-24 01:30:00       S109     Ang Mo Kio Avenue 5   103.849
# ...                   ...        ...                     ...       ...
# 13732 2017-05-24 17:10:00       S106                     NaN       NaN
# 13733 2017-05-24 01:35:00       S108    Marina Gardens Drive    103.87
# 13734 2017-05-24 01:40:00       S108    Marina Gardens Drive    103.87
# 13735 2017-05-24 16:45:00       S108    Marina Gardens Drive    103.87
# 13736 2017-05-24 16:50:00       S108    Marina Gardens Drive    103.87
# 13737 2017-05-24 00:20:00       S121  Old Choa Chu Kang Road   103.722
# 13738 2017-05-24 00:25:00       S121  Old Choa Chu Kang Road   103.722
# 13739 2017-05-24 00:30:00       S121  Old Choa Chu Kang Road   103.722
# 13740 2017-05-24 00:35:00       S121  Old Choa Chu Kang Road   103.722
# 13741 2017-05-24 03:00:00       S121  Old Choa Chu Kang Road   103.722
# 13742 2017-05-24 03:05:00       S121  Old Choa Chu Kang Road   103.722
# 13743 2017-05-24 03:10:00       S121  Old Choa Chu Kang Road   103.722
# 13744 2017-05-24 03:15:00       S121  Old Choa Chu Kang Road   103.722
# 13745 2017-05-24 03:20:00       S121  Old Choa Chu Kang Road   103.722
# 13746 2017-05-24 03:25:00       S121  Old Choa Chu Kang Road   103.722
# 13747 2017-05-24 03:45:00       S121  Old Choa Chu Kang Road   103.722
# 13748 2017-05-24 03:50:00       S121  Old Choa Chu Kang Road   103.722
# 13749 2017-05-24 04:20:00       S121  Old Choa Chu Kang Road   103.722
# 13750 2017-05-24 04:25:00       S121  Old Choa Chu Kang Road   103.722
# 13751 2017-05-24 07:15:00       S121  Old Choa Chu Kang Road   103.722
# 13752 2017-05-24 08:15:00       S121  Old Choa Chu Kang Road   103.722
# 13753 2017-05-24 08:50:00       S121  Old Choa Chu Kang Road   103.722
# 13754 2017-05-24 08:55:00       S121  Old Choa Chu Kang Road   103.722
# 13755 2017-05-24 09:00:00       S121  Old Choa Chu Kang Road   103.722
# 13756 2017-05-24 09:05:00       S121  Old Choa Chu Kang Road   103.722
# 13757 2017-05-24 09:25:00       S121  Old Choa Chu Kang Road   103.722
# 13758 2017-05-24 21:35:00       S121  Old Choa Chu Kang Road   103.722
# 13759 2017-05-24 22:40:00       S121  Old Choa Chu Kang Road   103.722
# 13760 2017-05-24 22:45:00       S121  Old Choa Chu Kang Road   103.722
# 13761 2017-05-24 22:50:00       S121  Old Choa Chu Kang Road   103.722
#
#       latitude  wind-speed  rainfall  air-temperature  relative-humidity
# 0       1.3764         5.3       NaN             29.3               78.0
# 1       1.3764         4.1       NaN             29.3               78.2
# 2       1.3764         4.7       NaN             29.3               77.7
# 3       1.3764         6.0       NaN             29.3               78.1
# 4       1.3764         NaN       0.0             29.3               78.1
# 5       1.3764         9.3       NaN             29.3               78.2
# 6       1.3764         NaN       0.0             29.3               78.2
# 7       1.3764         6.4       NaN             29.3               78.3
# 8       1.3764         NaN       0.0             29.3               78.3
# 9       1.3764         2.9       NaN             29.3               78.3
# 10      1.3764         NaN       0.0             29.3               78.3
# 11      1.3764         4.7       NaN             29.3               78.4
# 12      1.3764         NaN       0.0             29.3               78.4
# 13      1.3764         3.1       NaN             29.3               78.7
# 14      1.3764         NaN       0.0             29.3               78.7
# 15      1.3764         7.2       NaN             29.3               78.7
# 16      1.3764         NaN       0.0             29.3               78.7
# 17      1.3764        10.7       NaN             29.3               78.9
# 18      1.3764         NaN       0.0             29.3               78.9
# 19      1.3764         5.8       NaN             29.3               79.2
# 20      1.3764         4.5       NaN             29.2               79.4
# 21      1.3764         7.2       NaN             29.3               79.5
# 22      1.3764         7.4       NaN             29.2               79.6
# 23      1.3764         4.5       NaN             29.2               80.0
# 24      1.3764         NaN       0.0             29.2               80.0
# 25      1.3764         2.1       NaN             29.2               79.9
# 26      1.3764         NaN       0.0             29.2               79.9
# 27      1.3764         4.7       NaN             29.2               80.0
# 28      1.3764         NaN       0.0             29.2               80.0
# 29      1.3764         3.9       NaN             29.2               79.9
# ...        ...         ...       ...              ...                ...
# 13732      NaN         NaN       0.0              NaN                NaN
# 13733   1.2799         NaN       NaN             29.3               84.0
# 13734   1.2799         NaN       NaN             29.2               83.5
# 13735   1.2799         NaN       NaN             25.9               94.4
# 13736   1.2799         NaN       NaN             25.9               94.6
# 13737  1.37288         NaN       NaN             28.7               82.9
# 13738  1.37288         NaN       NaN             28.7               82.9
# 13739  1.37288         NaN       NaN             28.7               82.9
# 13740  1.37288         NaN       NaN             28.6               83.3
# 13741  1.37288         NaN       NaN             28.6               83.6
# 13742  1.37288         NaN       NaN             28.6               83.7
# 13743  1.37288         NaN       NaN             28.6               83.6
# 13744  1.37288         NaN       NaN             28.6               83.8
# 13745  1.37288         NaN       NaN             28.6               83.7
# 13746  1.37288         NaN       NaN             28.7               83.6
# 13747  1.37288         NaN       NaN             28.6               84.5
# 13748  1.37288         NaN       NaN             28.6               84.6
# 13749  1.37288         NaN       NaN             28.7               83.5
# 13750  1.37288         NaN       NaN             28.7               83.4
# 13751  1.37288         NaN       NaN             28.2               85.1
# 13752  1.37288         NaN       NaN             28.1               85.2
# 13753  1.37288         NaN       NaN             23.9               98.4
# 13754  1.37288         NaN       NaN             23.8               98.6
# 13755  1.37288         NaN       NaN             23.7               98.8
# 13756  1.37288         NaN       NaN             23.8               99.0
# 13757  1.37288         NaN       NaN             23.9               99.2
# 13758  1.37288         NaN       NaN             25.7               94.6
# 13759  1.37288         NaN       NaN             25.9               93.6
# 13760  1.37288         NaN       NaN             25.9               93.7
# 13761  1.37288         NaN       NaN             25.7               94.3
#
# [13762 rows x 9 columns]

# %%
outer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13762 entries, 0 to 13761
# Data columns (total 9 columns):
# timestamp (SGT)      13762 non-null datetime64[ns]
# station_id           13762 non-null object
# name                 3770 non-null object
# longitude            3770 non-null object
# latitude             3770 non-null object
# wind-speed           3660 non-null float64
# rainfall             13196 non-null float64
# air-temperature      4435 non-null float64
# relative-humidity    3946 non-null float64
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 1.0+ MB

# %%
outer_df.groupby('name').describe()
# Out:
#                         air-temperature                                   \
#                                   count       mean       std   min   25%
# name
# Ang Mo Kio Avenue 5               448.0  26.684152  1.751559  23.5  25.4
# Banyan Road                       289.0  26.732872  1.582563  24.1  25.5
# Clementi Road                     289.0  26.049827  1.741410  23.2  25.0
# East Coast Parkway                268.0  27.587313  1.819142  24.4  26.2
# Kim Chuan Road                    289.0  27.175779  1.905612  24.1  25.9
# Marina Gardens Drive              289.0  26.976125  1.918265  24.0  25.5
# Old Choa Chu Kang Road            289.0  26.238754  1.704595  23.2  24.8
# Semakau Landfill                  284.0  27.398239  1.560544  25.1  25.9
# Tuas South Avenue 3               289.0  26.613149  1.823201  23.8  25.0
# Upper Changi Road North           289.0  26.726644  1.824967  24.0  25.3
# West Coast Highway                270.0  27.326296  1.804582  24.7  26.0
# Woodlands Avenue 9                189.0  27.375661  1.274020  25.5  26.1
# Woodlands Road                    288.0  26.634375  1.631281  23.7  25.4
#
#                                           rainfall            ...   \
#                           50%   75%   max    count      mean  ...
# name                                                          ...
# Ang Mo Kio Avenue 5      25.8  28.8  29.5    180.0  0.045556  ...
# Banyan Road              26.3  28.6  29.2    289.0  0.116263  ...
# Clementi Road            25.5  27.9  28.9    289.0  0.143945  ...
# East Coast Parkway       27.5  29.4  29.9    263.0  0.061597  ...
# Kim Chuan Road           26.3  29.4  30.3    286.0  0.080420  ...
# Marina Gardens Drive     26.1  29.1  30.1    285.0  0.107368  ...
# Old Choa Chu Kang Road   25.8  28.1  29.0    264.0  0.200758  ...
# Semakau Landfill         27.0  29.2  29.5    258.0  0.072868  ...
# Tuas South Avenue 3      26.1  28.8  29.5    289.0  0.102422  ...
# Upper Changi Road North  25.8  28.7  29.7    229.0  0.034061  ...
# West Coast Highway       26.4  29.4  29.8    270.0  0.035556  ...
# Woodlands Avenue 9       27.7  28.7  29.2    175.0  0.001143  ...
# Woodlands Road           26.1  28.2  29.3    209.0  0.150239  ...
#
#                         relative-humidity        wind-speed             \
#                                       75%    max      count       mean
# name
# Ang Mo Kio Avenue 5                96.000  100.8      268.0   4.758955
# Banyan Road                        92.700   98.2      289.0   6.411764
# Clementi Road                      96.200   99.3      289.0   5.933218
# East Coast Parkway                 94.025  100.8      268.0   7.429477
# Kim Chuan Road                     93.400   97.8      289.0   4.515917
# Marina Gardens Drive               94.900   97.9        0.0        NaN
# Old Choa Chu Kang Road             97.800   99.2        0.0        NaN
# Semakau Landfill                   94.600  100.9      284.0  10.772183
# Tuas South Avenue 3                92.300   93.1      289.0   3.435640
# Upper Changi Road North            93.900   96.4      289.0   6.128373
# West Coast Highway                 97.900  100.9      270.0   6.276296
# Woodlands Avenue 9                100.000  101.0      189.0   4.632804
# Woodlands Road                     95.600   97.7      288.0   2.717361
#
#
#                               std  min   25%  50%    75%   max
# name
# Ang Mo Kio Avenue 5      2.751825  0.6  2.70  4.5   6.20  15.7
# Banyan Road              3.346100  0.4  3.90  6.2   8.50  16.5
# Clementi Road            3.711479  0.6  2.90  5.6   7.80  21.6
# East Coast Parkway       3.005486  1.4  5.10  7.8   9.35  20.2
# Kim Chuan Road           2.546394  0.6  2.50  4.5   6.00  16.9
# Marina Gardens Drive          NaN  NaN   NaN  NaN    NaN   NaN
# Old Choa Chu Kang Road        NaN  NaN   NaN  NaN    NaN   NaN
# Semakau Landfill         4.551849  3.1  8.15  9.5  12.10  25.7
# Tuas South Avenue 3      2.848040  0.4  1.70  2.7   4.10  17.7
# Upper Changi Road North  2.876525  0.6  4.10  6.6   8.20  15.2
# West Coast Highway       3.810945  0.8  3.90  5.7   7.80  28.2
# Woodlands Avenue 9       2.822569  0.6  2.90  4.1   5.60  19.2
# Woodlands Road           2.144885  0.4  1.40  2.1   3.30  14.6
#
# [13 rows x 32 columns]

# %%
outer_df.to_csv('output.csv', index = False)
