# %% [markdown]
# # carpark_data_gov_sg_api
#
# ## Purpose:
# Explore the carpark availaability APIs at https://developers.data.gov.sg.
#
# ## History:
# - 2018-04-18 - Shi Yuan: API Key not required since Feb 2018, code changes

# %%
import matplotlib.pyplot as plt
import pandas as pd
import requests
import seaborn as sns
from tqdm import tqdm

# %matplotlib inline

# %%
# Not required since Feb 2018

## Get my API keys
#from my_api_keys import my_api_dict
## Note: this module, containing my API keys, will not be shared via GitHub
## You can obtain your own API key(s) by registering at https://developers.data.gov.sg
#my_key = my_api_dict['data.gov.sg']  # API key for data.gov.sg

# %% [markdown]
# ## Meta-data for available meteorological APIs
# [I added this section after exploring the wind-speed data - see below.]

# %%
# Meteorological variables
for variable in tqdm(['rainfall', 'wind-speed', 'wind-direction', 'air-temperature', 'relative-humidity']):
    print(variable)
    r = requests.get('https://api.data.gov.sg/v1/environment/{}'.format(variable))
    metadata = r.json()['metadata']
    for key in metadata.keys():
        if key != 'stations':  # don't print information about stations
            print('  {}: {}'.format(key, r.json()['metadata'][key]))
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# rainfall
#   reading_type: TB1 Rainfall 5 Minute Total F
#   reading_unit: mm
#  20%|██        | 1/5 [00:00<00:00,  4.95it/s]
# wind-speed
#   reading_type: Wind Speed AVG(S)10M M1M
#   reading_unit: knots
#  40%|████      | 2/5 [00:00<00:00,  4.26it/s]
# wind-direction
#   reading_type: Wind Dir AVG (S) 10M M1M
#   reading_unit: degrees
#  60%|██████    | 3/5 [00:00<00:00,  5.18it/s]
# air-temperature
#   reading_type: DBT 1M F
#   reading_unit: deg C
#  80%|████████  | 4/5 [00:00<00:00,  5.09it/s]
# relative-humidity
#   reading_type: RH 1M F
#   reading_unit: percentage
# 100%|██████████| 5/5 [00:01<00:00,  4.70it/s]

# %%
# Meteorological variables
for variable in ['rainfall', 'wind-speed', 'wind-direction', 'air-temperature', 'relative-humidity']:
    print(variable)
    r = requests.get('https://api.data.gov.sg/v1/environment/{}'.format(variable))
    metadata = r.json()['metadata']
    for key in metadata.keys():
        if key == 'stations':  # print information about stations
            print('  {}: {}'.format(key, r.json()['metadata'][key]))
# Out:
# rainfall
#   stations: [{'id': 'S77', 'device_id': 'S77', 'name': 'Alexandra Road', 'location': {'latitude': 1.2937, 'longitude': 103.8125}}, {'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S55', 'device_id': 'S55', 'name': 'Buangkok Green', 'location': {'latitude': 1.3837, 'longitude': 103.886}}, {'id': 'S64', 'device_id': 'S64', 'name': 'Bukit Panjang Road', 'location': {'latitude': 1.3824, 'longitude': 103.7603}}, {'id': 'S90', 'device_id': 'S90', 'name': 'Bukit Timah Road', 'location': {'latitude': 1.3191, 'longitude': 103.8191}}, {'id': 'S61', 'device_id': 'S61', 'name': 'Chai Chee Street', 'location': {'latitude': 1.323, 'longitude': 103.9217}}, {'id': 'S114', 'device_id': 'S114', 'name': 'Choa Chu Kang Avenue 4', 'location': {'latitude': 1.38, 'longitude': 103.73}}, {'id': 'S11', 'device_id': 'S11', 'name': 'Choa Chu Kang Road', 'location': {'latitude': 1.3746, 'longitude': 103.6938}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S101', 'device_id': 'S101', 'name': 'Corporation Road', 'location': {'latitude': 1.35053, 'longitude': 103.7134}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S215', 'device_id': 'S215', 'name': 'GEYLANG EAST CENTRAL', 'location': {'latitude': 1.32785, 'longitude': 103.88899}}, {'id': 'S118', 'device_id': 'S118', 'name': 'Handy Road', 'location': {'latitude': 1.2994, 'longitude': 103.8461}}, {'id': 'S120', 'device_id': 'S120', 'name': 'Holland Road', 'location': {'latitude': 1.30874, 'longitude': 103.818}}, {'id': 'S33', 'device_id': 'S33', 'name': 'Jurong Pier Road', 'location': {'latitude': 1.3081, 'longitude': 103.71}}, {'id': 'S71', 'device_id': 'S71', 'name': 'Kent Ridge Road', 'location': {'latitude': 1.2923, 'longitude': 103.7815}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S66', 'device_id': 'S66', 'name': 'Kranji Way', 'location': {'latitude': 1.4387, 'longitude': 103.7363}}, {'id': 'S112', 'device_id': 'S112', 'name': 'Lim Chu Kang Road', 'location': {'latitude': 1.43854, 'longitude': 103.70131}}, {'id': 'S07', 'device_id': 'S07', 'name': 'Lornie Road', 'location': {'latitude': 1.3415, 'longitude': 103.8334}}, {'id': 'S40', 'device_id': 'S40', 'name': 'Mandai Lake Road', 'location': {'latitude': 1.4044, 'longitude': 103.78962}}, {'id': 'S108', 'device_id': 'S108', 'name': 'Marina Gardens Drive', 'location': {'latitude': 1.2799, 'longitude': 103.8703}}, {'id': 'S113', 'device_id': 'S113', 'name': 'Marine Parade Road', 'location': {'latitude': 1.30648, 'longitude': 103.9104}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S119', 'device_id': 'S119', 'name': 'Nicoll Highway', 'location': {'latitude': 1.30105, 'longitude': 103.8666}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S35', 'device_id': 'S35', 'name': 'Old Toh Tuck Road', 'location': {'latitude': 1.3329, 'longitude': 103.7556}}, {'id': 'S29', 'device_id': 'S29', 'name': 'Pasir Ris Drive 12', 'location': {'latitude': 1.387, 'longitude': 103.935}}, {'id': 'S94', 'device_id': 'S94', 'name': 'Pasir Ris Street 51', 'location': {'latitude': 1.3662, 'longitude': 103.9528}}, {'id': 'S78', 'device_id': 'S78', 'name': 'Poole Road', 'location': {'latitude': 1.30703, 'longitude': 103.89067}}, {'id': 'S106', 'device_id': 'S106', 'name': 'Pulau Ubin', 'location': {'latitude': 1.4168, 'longitude': 103.9673}}, {'id': 'S81', 'device_id': 'S81', 'name': 'Punggol Central', 'location': {'latitude': 1.4029, 'longitude': 103.9092}}, {'id': 'S111 ...
# wind-speed
#   stations: [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S106', 'device_id': 'S106', 'name': 'Pulau Ubin', 'location': {'latitude': 1.4168, 'longitude': 103.9673}}, {'id': 'S102', 'device_id': 'S102', 'name': 'Semakau Landfill', 'location': {'latitude': 1.189, 'longitude': 103.768}}, {'id': 'S122', 'device_id': 'S122', 'name': 'Sembawang Road', 'location': {'latitude': 1.41731, 'longitude': 103.8249}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}, {'id': 'S100', 'device_id': 'S100', 'name': 'Woodlands Road', 'location': {'latitude': 1.4172, 'longitude': 103.74855}}]
# wind-direction
#   stations: [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S106', 'device_id': 'S106', 'name': 'Pulau Ubin', 'location': {'latitude': 1.4168, 'longitude': 103.9673}}, {'id': 'S102', 'device_id': 'S102', 'name': 'Semakau Landfill', 'location': {'latitude': 1.189, 'longitude': 103.768}}, {'id': 'S122', 'device_id': 'S122', 'name': 'Sembawang Road', 'location': {'latitude': 1.41731, 'longitude': 103.8249}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}, {'id': 'S100', 'device_id': 'S100', 'name': 'Woodlands Road', 'location': {'latitude': 1.4172, 'longitude': 103.74855}}]
# air-temperature
#   stations: [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S108', 'device_id': 'S108', 'name': 'Marina Gardens Drive', 'location': {'latitude': 1.2799, 'longitude': 103.8703}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S122', 'device_id': 'S122', 'name': 'Sembawang Road', 'location': {'latitude': 1.41731, 'longitude': 103.8249}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}, {'id': 'S100', 'device_id': 'S100', 'name': 'Woodlands Road', 'location': {'latitude': 1.4172, 'longitude': 103.74855}}]
# relative-humidity
#   stations: [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S108', 'device_id': 'S108', 'name': 'Marina Gardens Drive', 'location': {'latitude': 1.2799, 'longitude': 103.8703}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S122', 'device_id': 'S122', 'name': 'Sembawang Road', 'location': {'latitude': 1.41731, 'longitude': 103.8249}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}, {'id': 'S100', 'device_id': 'S100', 'name': 'Woodlands Road', 'location': {'latitude': 1.4172, 'longitude': 103.74855}}]

# %%
#metadata.keys()

# %% [markdown]
# ## Specify Date

# %%
date = '2018-01-08'
datetime = date + ' 00:05:00'
datetime
# Out:
# '2018-01-08 00:05:00'

# %% [markdown]
# ## Carpark Availability - debug

# %%
# Get carpark availability at 30min interval - debug periods
carpark_df = pd.DataFrame(columns=['lot_type', 'total_lots', 'lots_available', 'timestamp (SGT)'])
for dt in tqdm(pd.date_range(datetime, periods=1, freq='30min')):  # I remember this was a wet day
    r = requests.get('https://api.data.gov.sg/v1/transport/carpark-availability',
                     params={'date_time': dt.strftime('%Y-%m-%dT%H:%M:%S')})
    temp_df = pd.DataFrame(r.json()['items'][0]['carpark_data'])
    #temp_df = temp_df.rename(columns={'lots_available': 'lots_available'})
    temp_df['timestamp (SGT)'] = pd.to_datetime(r.json()['items'][0]['timestamp'].split('+')[0])
    carpark_df = carpark_df.append(temp_df, ignore_index=True)
carpark_df.head()
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.56s/it]
#                                         carpark_info carpark_number lot_type  \
# 0  [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12      NaN
# 1  [{'total_lots': '583', 'lot_type': 'C', 'lots_...            HLM      NaN
# 2  [{'total_lots': '329', 'lot_type': 'C', 'lots_...            RHM      NaN
# 3  [{'total_lots': '110', 'lot_type': 'C', 'lots_...           BM29      NaN
# 4  [{'total_lots': '97', 'lot_type': 'C', 'lots_a...            Q81      NaN
#
#   lots_available     timestamp (SGT) total_lots      update_datetime
# 0            NaN 2018-04-17 00:04:28        NaN  2018-04-17T00:03:23
# 1            NaN 2018-04-17 00:04:28        NaN  2018-04-17T00:03:40
# 2            NaN 2018-04-17 00:04:28        NaN  2018-04-17T00:03:21
# 3            NaN 2018-04-17 00:04:28        NaN  2017-08-01T12:15:17
# 4            NaN 2018-04-17 00:04:28        NaN  2018-04-17T00:03:38

# %% [markdown]
# ## Read carpark info file

# %%
info_df = pd.read_csv("hdb-carpark-information.csv")
info_df.head()
# Out:
#   car_park_no                                      address     x_coord  \
# 0         ACB  BLK 270/271 ALBERT CENTRE BASEMENT CAR PARK  30314.7936
# 1         ACM                    BLK 98A ALJUNIED CRESCENT  33758.4143
# 2         AH1                          BLK 101 JALAN DUSUN  29257.7203
# 3        AK19               BLOCK 253 ANG MO KIO STREET 21  28185.4359
# 4        AK31                 BLK 302/348 ANG MO KIO ST 31  29482.0290
#
#       y_coord          car_park_type type_of_parking_system  \
# 0  31490.4942      BASEMENT CAR PARK     ELECTRONIC PARKING
# 1  33695.5198  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2  34500.3599       SURFACE CAR PARK     ELECTRONIC PARKING
# 3  39012.6664       SURFACE CAR PARK         COUPON PARKING
# 4  38684.1754       SURFACE CAR PARK         COUPON PARKING
#
#   short_term_parking             free_parking night_parking
# 0          WHOLE DAY                       NO           YES
# 1          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 3            7AM-7PM                       NO            NO
# 4                 NO                       NO            NO

# %%
info_df = info_df.rename(columns={'car_park_no': 'carpark_number'})
#info_df = info_df.rename(columns={'x_coord': 'longitude'})
#info_df = info_df.rename(columns={'y_coord': 'latitude'})
info_df
# Out:
#      carpark_number                                        address  \
# 0               ACB    BLK 270/271 ALBERT CENTRE BASEMENT CAR PARK
# 1               ACM                      BLK 98A ALJUNIED CRESCENT
# 2               AH1                            BLK 101 JALAN DUSUN
# 3              AK19                 BLOCK 253 ANG MO KIO STREET 21
# 4              AK31                   BLK 302/348 ANG MO KIO ST 31
# 5              AK52                     BLOCK 513 ANG MO KIO ST 53
# 6               AK6                     BLOCK 728 ANG MO KIO AVE 6
# 7              AK83  BLK 5022 TO 5095 ANG MO KIO INDUSTRIAL PARK 2
# 8               AK9                            ANG MO KIO AVENUE 9
# 9              AM16                  BLK 256A ANG MO KIO STREET 21
# 10             AM18                      BLK 308C ANG MO KIO AVE 1
# 11             AM19                       BLK 260 ANG MO KIO ST 21
# 12             AM20                      BLK 309B ANG MO KIO ST 31
# 13             AM22                  BLK 316B ANG MO KIO STREET 31
# 14             AM32                      BLK 255A ANG MO KIO ST 21
# 15             AM43                       BLK 455 ANG MO KIO ST 44
# 16             AM46                   BLK 588 ANG MO KIO STREET 52
# 17             AM51                       BLK 700 ANG MO KIO AVE 6
# 18             AM64                       BLK 590 ANG MO KIO ST 51
# 19             AM79                  BLK 596 ANG MO KIO STREEET 52
# 20             AM80                      BLK 130A ANG MO KIO ST 12
# 21             AM81                      BLK 132A ANG MO KIO ST 12
# 22             AM96                  BLK 352A ANG MO KIO STREET 32
# 23             AR1L                             3 AND 5 DOVER ROAD
# 24             AR1M                              BLK 2A DOVER ROAD
# 25             AR2L                   BLK 26 AND 27 DOVER CRESCENT
# 26             AR2M                          BLK 28 DOVER CRESCENT
# 27             AR5M                         BLK 19A DOVER CRESCENT
# 28             AR7L                      12 TO 14 DOVER CLOSE EAST
# 29             AR7M                       BLK 12A DOVER CLOSE EAST
# ...             ...                                            ...
# 2036             Y5                   BLK 144/149 YISHUN STREET 11
# 2037            Y51       BLK 423/427, 433/440 YISHUN AVE 6/AVE 11
# 2038           Y51M                          BLK 441 YISHUN AVE 11
# 2039           Y52M                          BLK 456A YISHUN ST 41
# 2040           Y53M                          BLK 426 YISHUN AVE 11
# 2041           Y54M                       BLK 925 YISHUN CENTRAL 1
# 2042            Y56           BLK 926/932,934/935 YISHUN CENTRAL 1
# 2043            Y57         BLK 415/417 YISHUN RING ROAD/AVENUE 11
# 2044            Y58                           162 YISHUN STREET 11
# 2045           Y59M                          BLK 429 YISHUN AVE 11
# 2046             Y6                   BLK 150/161 YISHUN STREET 11
# 2047           Y60M                          BLK 430 YISHUN AVE 11
# 2048           Y61M                           BLK 431 YISHUN AVE 1
# 2049           Y62M                     BLOCK 342 YISHUN RING ROAD
# 2050           Y63M                           BLK 333 YISHUN ST 31
# 2051           Y64M                           BLK 334 YISHUN ST 31
# 2052           Y65M                           BLK 315 YISHUN AVE 9
# 2053           Y66M                           BLK 317 YISHUN AVE 9
# 2054            Y67                        269A, 269B YISHUN ST 22
# 2055           Y68M                           BLK 504 YISHUN ST 51
# 2056           Y69M                     BLOCK 513 YISHUN STREET 51
# 2057             Y7             BLK 701/716 & 701B YISHUN AVENUE 5
# 2058           Y70M                           BLK 506 YISHUN AVE 4
# 2059           Y71M                           BLK 501 YISHUN ST 51
# 2060           Y72M                           512 YISHUN STREET 51
# 2061           Y73M                      BLOCK 671 YISHUN AVENUE 4
# 2062           Y74M                      BLOCK 673 YISHUN AVENUE 4
# 2063           Y75M                      BLOCK 674 YISHUN AVENUE 4
# 2064             Y8       BLK 731/746 YISHUN STREET 71,72/AVENUE 5
# 2065             Y9                   BLK 747/752 YISHUN STREET 72
#
#          x_coord     y_coord          car_park_type type_of_parking_system  \
# 0     30314.7936  31490.4942      BASEMENT CAR PARK     ELECTRONIC PARKING
# 1     33758.4143  33695.5198  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2     29257.7203  34500.3599       SURFACE CAR PARK     ELECTRONIC PARKING
# 3     28185.4359  39012.6664       SURFACE CAR PARK         COUPON PARKING
# 4     29482.0290  38684.1754       SURFACE CAR PARK         COUPON PARKING
# 5     29889.3457  39382.8134       SURFACE CAR PARK         COUPON PARKING
# 6     29283.7324  39647.8906       SURFACE CAR PARK         COUPON PARKING
# 7     31397.2241  39851.6191       SURFACE CAR PARK         COUPON PARKING
# 8     29674.8184  40616.8750       SURFACE CAR PARK         COUPON PARKING
# 9     28267.0582  39151.8344  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 10    29257.6457  38619.9953  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 11    28134.9305  38989.9965  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 12    29421.1502  38526.8611  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 13    29595.2539  38514.7606  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 14    28117.7689  39172.0389  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 15    30669.9488  38956.6191  MULTI-STOREY CAR PARK         COUPON PARKING
# 16    30234.4145  39354.0323  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 17    29489.0250  39103.7605  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 18    30201.2360  39274.2740  MULTI-STOREY CAR PARK         COUPON PARKING
# 19    30004.2224  39370.6063  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 20    28950.7223  39184.6976  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 21    28960.3285  39294.4158  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 22    29961.0968  38457.9118  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 23    22359.0217  31801.6379       SURFACE CAR PARK     ELECTRONIC PARKING
# 24    22474.2050  31687.9608  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 25    22194.6359  32026.8288       SURFACE CAR PARK     ELECTRONIC PARKING
# 26    22252.4860  31896.9749  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 27    22562.8641  32184.9758  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 28    22688.3753  32015.1518       SURFACE CAR PARK     ELECTRONIC PARKING
# 29    22643.9533  31900.5591  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# ...          ...         ...                    ...                    ...
# 2036  27865.2344  45870.8907       SURFACE CAR PARK     ELECTRONIC PARKING
# 2037  29529.8300  44808.1062       SURFACE CAR PARK     ELECTRONIC PARKING
# 2038  29363.3139  44945.2291  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2039  29291.1048  44676.2316  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2040  29413.0818  44965.2268  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2041  28413.6222  45450.4144  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2042  28383.2891  45244.5078       SURFACE CAR PARK     ELECTRONIC PARKING
# 2043  29463.1113  45083.3281       SURFACE CAR PARK     ELECTRONIC PARKING
# 2044  27895.8292  46028.4287       SURFACE CAR PARK     ELECTRONIC PARKING
# 2045  29764.6921  44893.3273  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2046  28097.4355  46026.6367       SURFACE CAR PARK     ELECTRONIC PARKING
# 2047  29647.1253  44767.6656  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2048  29588.0070  44651.6313  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2049  29238.4163  45775.1779      BASEMENT CAR PARK     ELECTRONIC PARKING
# 2050  29302.8265  45929.6846  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2051  29314.7149  46022.7799  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2052  28968.6232  46042.7580  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2053  28998.1897  46163.9678  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2054  28843.2023  46462.2763       SURFACE CAR PARK         COUPON PARKING
# 2055  29255.0052  44464.5975  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2056  29198.3675  44200.6403  MULTI-STOREY CAR PARK         COUPON PARKING
# 2057  27346.9746  45449.3008       SURFACE CAR PARK     ELECTRONIC PARKING
# 2058  28784.6363  44073.0438  MULTI-STOREY CAR PARK         COUPON PARKING
# 2059  28844.5948  44263.7102  MULTI-STOREY CAR PARK         COUPON PARKING
# 2060  28880.6176  44062.2578  MULTI-STOREY CAR PARK         COUPON PARKING
# 2061  28917.4786  44546.2792  MULTI-STOREY CAR PARK         COUPON PARKING
# 2062  28931.6439  44600.7404  MULTI-STOREY CAR PARK         COUPON PARKING
# 2063  29086.6991  44661.4096  MULTI-STOREY CAR PARK         COUPON PARKING
# 2064  27772.9219  45686.2734       SURFACE CAR PARK     ELECTRONIC PARKING
# 2065  28077.2305  45507.8047       SURFACE CAR PARK     ELECTRONIC PARKING
#
#      short_term_parking             free_parking night_parking
# 0             WHOLE DAY                       NO           YES
# 1             WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2             WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 3               7AM-7PM                       NO            NO
# 4                    NO                       NO            NO
# 5             WHOLE DAY                       NO           YES
# 6           7AM-10.30PM  SUN & PH FR 7AM-10.30PM            NO
# 7                    NO                       NO            NO
# 8                    NO                       NO            NO
# 9             WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 10          7AM-10.30PM                       NO            NO
# 11          7AM-10.30PM                       NO            NO
# 12            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 13            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 14          7AM-10.30PM                       NO            NO
# 15          7AM-10.30PM                       NO            NO
# 16          7AM-10.30PM                       NO            NO
# 17            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 18          7AM-10.30PM                       NO            NO
# 19            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 20            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 21            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 22            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 23                   NO                       NO            NO
# 24            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 25                   NO                       NO            NO
# 26            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 27            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 28                   NO                       NO            NO
# 29            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# ...                 ...                      ...           ...
# 2036        7AM-10.30PM  SUN & PH FR 7AM-10.30PM            NO
# 2037        7AM-10.30PM  SUN & PH FR 7AM-10.30PM            NO
# 2038          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2039          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2040          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2041          WHOLE DAY                       NO           YES
# 2042        7AM-10.30PM                       NO            NO
# 2043            7AM-7PM                       NO            NO
# 2044        7AM-10.30PM                       NO            NO
# 2045          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2046        7AM-10.30PM  SUN & PH FR 7AM-10.30PM            NO
# 2047          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2048          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2049          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2050          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2051          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2052          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2053          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2054        7AM-10.30PM                       NO            NO
# 2055          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2056          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2057          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2058          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2059          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2060          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2061          WHOLE DAY                       NO           YES
# 2062          WHOLE DAY                       NO           YES
# 2063          WHOLE DAY                       NO           YES
# 2064          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
# 2065          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES
#
# [2066 rows x 9 columns]

# %%
def SVY21toWGS84(X,Y):
    r = requests.get('https://developers.onemap.sg/commonapi/convert/3414to4326',
                     params={'X': X, 'Y':Y})
    return r.json()

# %%
info_df['x_coord'][0]
# Out:
# 30314.7936

# %%
info_df['y_coord'][0]
# Out:
# 31490.4942

# %%
result = SVY21toWGS84(info_df['x_coord'][1],info_df['y_coord'][1])
result['longitude']
result['latitude']
# Out:
# 1.321004290105958

# %%
len(info_df)
# Out:
# 2066

# %%
info_df['longitude']=''
info_df['latitude']=''
for i in tqdm(range(0,len(info_df))):
    result = SVY21toWGS84(info_df['x_coord'][i],info_df['y_coord'][i])
    info_df['longitude'][i]= result['longitude']
    info_df['latitude'][i]= result['latitude']
info_df
# Out:
#   0%|          | 0/2066 [00:00<?, ?it/s]C:\Users\User\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 100%|██████████| 2066/2066 [05:17<00:00,  6.51it/s]

# %%
info_df
# Out:
#      carpark_number                                        address  \
# 0               ACB    BLK 270/271 ALBERT CENTRE BASEMENT CAR PARK
# 1               ACM                      BLK 98A ALJUNIED CRESCENT
# 2               AH1                            BLK 101 JALAN DUSUN
# 3              AK19                 BLOCK 253 ANG MO KIO STREET 21
# 4              AK31                   BLK 302/348 ANG MO KIO ST 31
# 5              AK52                     BLOCK 513 ANG MO KIO ST 53
# 6               AK6                     BLOCK 728 ANG MO KIO AVE 6
# 7              AK83  BLK 5022 TO 5095 ANG MO KIO INDUSTRIAL PARK 2
# 8               AK9                            ANG MO KIO AVENUE 9
# 9              AM16                  BLK 256A ANG MO KIO STREET 21
# 10             AM18                      BLK 308C ANG MO KIO AVE 1
# 11             AM19                       BLK 260 ANG MO KIO ST 21
# 12             AM20                      BLK 309B ANG MO KIO ST 31
# 13             AM22                  BLK 316B ANG MO KIO STREET 31
# 14             AM32                      BLK 255A ANG MO KIO ST 21
# 15             AM43                       BLK 455 ANG MO KIO ST 44
# 16             AM46                   BLK 588 ANG MO KIO STREET 52
# 17             AM51                       BLK 700 ANG MO KIO AVE 6
# 18             AM64                       BLK 590 ANG MO KIO ST 51
# 19             AM79                  BLK 596 ANG MO KIO STREEET 52
# 20             AM80                      BLK 130A ANG MO KIO ST 12
# 21             AM81                      BLK 132A ANG MO KIO ST 12
# 22             AM96                  BLK 352A ANG MO KIO STREET 32
# 23             AR1L                             3 AND 5 DOVER ROAD
# 24             AR1M                              BLK 2A DOVER ROAD
# 25             AR2L                   BLK 26 AND 27 DOVER CRESCENT
# 26             AR2M                          BLK 28 DOVER CRESCENT
# 27             AR5M                         BLK 19A DOVER CRESCENT
# 28             AR7L                      12 TO 14 DOVER CLOSE EAST
# 29             AR7M                       BLK 12A DOVER CLOSE EAST
# ...             ...                                            ...
# 2036             Y5                   BLK 144/149 YISHUN STREET 11
# 2037            Y51       BLK 423/427, 433/440 YISHUN AVE 6/AVE 11
# 2038           Y51M                          BLK 441 YISHUN AVE 11
# 2039           Y52M                          BLK 456A YISHUN ST 41
# 2040           Y53M                          BLK 426 YISHUN AVE 11
# 2041           Y54M                       BLK 925 YISHUN CENTRAL 1
# 2042            Y56           BLK 926/932,934/935 YISHUN CENTRAL 1
# 2043            Y57         BLK 415/417 YISHUN RING ROAD/AVENUE 11
# 2044            Y58                           162 YISHUN STREET 11
# 2045           Y59M                          BLK 429 YISHUN AVE 11
# 2046             Y6                   BLK 150/161 YISHUN STREET 11
# 2047           Y60M                          BLK 430 YISHUN AVE 11
# 2048           Y61M                           BLK 431 YISHUN AVE 1
# 2049           Y62M                     BLOCK 342 YISHUN RING ROAD
# 2050           Y63M                           BLK 333 YISHUN ST 31
# 2051           Y64M                           BLK 334 YISHUN ST 31
# 2052           Y65M                           BLK 315 YISHUN AVE 9
# 2053           Y66M                           BLK 317 YISHUN AVE 9
# 2054            Y67                        269A, 269B YISHUN ST 22
# 2055           Y68M                           BLK 504 YISHUN ST 51
# 2056           Y69M                     BLOCK 513 YISHUN STREET 51
# 2057             Y7             BLK 701/716 & 701B YISHUN AVENUE 5
# 2058           Y70M                           BLK 506 YISHUN AVE 4
# 2059           Y71M                           BLK 501 YISHUN ST 51
# 2060           Y72M                           512 YISHUN STREET 51
# 2061           Y73M                      BLOCK 671 YISHUN AVENUE 4
# 2062           Y74M                      BLOCK 673 YISHUN AVENUE 4
# 2063           Y75M                      BLOCK 674 YISHUN AVENUE 4
# 2064             Y8       BLK 731/746 YISHUN STREET 71,72/AVENUE 5
# 2065             Y9                   BLK 747/752 YISHUN STREET 72
#
#          x_coord     y_coord          car_park_type type_of_parking_system  \
# 0     30314.7936  31490.4942      BASEMENT CAR PARK     ELECTRONIC PARKING
# 1     33758.4143  33695.5198  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2     29257.7203  34500.3599       SURFACE CAR PARK     ELECTRONIC PARKING
# 3     28185.4359  39012.6664       SURFACE CAR PARK         COUPON PARKING
# 4     29482.0290  38684.1754       SURFACE CAR PARK         COUPON PARKING
# 5     29889.3457  39382.8134       SURFACE CAR PARK         COUPON PARKING
# 6     29283.7324  39647.8906       SURFACE CAR PARK         COUPON PARKING
# 7     31397.2241  39851.6191       SURFACE CAR PARK         COUPON PARKING
# 8     29674.8184  40616.8750       SURFACE CAR PARK         COUPON PARKING
# 9     28267.0582  39151.8344  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 10    29257.6457  38619.9953  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 11    28134.9305  38989.9965  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 12    29421.1502  38526.8611  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 13    29595.2539  38514.7606  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 14    28117.7689  39172.0389  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 15    30669.9488  38956.6191  MULTI-STOREY CAR PARK         COUPON PARKING
# 16    30234.4145  39354.0323  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 17    29489.0250  39103.7605  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 18    30201.2360  39274.2740  MULTI-STOREY CAR PARK         COUPON PARKING
# 19    30004.2224  39370.6063  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 20    28950.7223  39184.6976  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 21    28960.3285  39294.4158  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 22    29961.0968  38457.9118  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 23    22359.0217  31801.6379       SURFACE CAR PARK     ELECTRONIC PARKING
# 24    22474.2050  31687.9608  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 25    22194.6359  32026.8288       SURFACE CAR PARK     ELECTRONIC PARKING
# 26    22252.4860  31896.9749  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 27    22562.8641  32184.9758  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 28    22688.3753  32015.1518       SURFACE CAR PARK     ELECTRONIC PARKING
# 29    22643.9533  31900.5591  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# ...          ...         ...                    ...                    ...
# 2036  27865.2344  45870.8907       SURFACE CAR PARK     ELECTRONIC PARKING
# 2037  29529.8300  44808.1062       SURFACE CAR PARK     ELECTRONIC PARKING
# 2038  29363.3139  44945.2291  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2039  29291.1048  44676.2316  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2040  29413.0818  44965.2268  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2041  28413.6222  45450.4144  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2042  28383.2891  45244.5078       SURFACE CAR PARK     ELECTRONIC PARKING
# 2043  29463.1113  45083.3281       SURFACE CAR PARK     ELECTRONIC PARKING
# 2044  27895.8292  46028.4287       SURFACE CAR PARK     ELECTRONIC PARKING
# 2045  29764.6921  44893.3273  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2046  28097.4355  46026.6367       SURFACE CAR PARK     ELECTRONIC PARKING
# 2047  29647.1253  44767.6656  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2048  29588.0070  44651.6313  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2049  29238.4163  45775.1779      BASEMENT CAR PARK     ELECTRONIC PARKING
# 2050  29302.8265  45929.6846  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2051  29314.7149  46022.7799  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2052  28968.6232  46042.7580  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2053  28998.1897  46163.9678  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2054  28843.2023  46462.2763       SURFACE CAR PARK         COUPON PARKING
# 2055  29255.0052  44464.5975  MULTI-STOREY CAR PARK     ELECTRONIC PARKING
# 2056  29198.3675  44200.6403  MULTI-STOREY CAR PARK         COUPON PARKING
# 2057  27346.9746  45449.3008       SURFACE CAR PARK     ELECTRONIC PARKING
# 2058  28784.6363  44073.0438  MULTI-STOREY CAR PARK         COUPON PARKING
# 2059  28844.5948  44263.7102  MULTI-STOREY CAR PARK         COUPON PARKING
# 2060  28880.6176  44062.2578  MULTI-STOREY CAR PARK         COUPON PARKING
# 2061  28917.4786  44546.2792  MULTI-STOREY CAR PARK         COUPON PARKING
# 2062  28931.6439  44600.7404  MULTI-STOREY CAR PARK         COUPON PARKING
# 2063  29086.6991  44661.4096  MULTI-STOREY CAR PARK         COUPON PARKING
# 2064  27772.9219  45686.2734       SURFACE CAR PARK     ELECTRONIC PARKING
# 2065  28077.2305  45507.8047       SURFACE CAR PARK     ELECTRONIC PARKING
#
#      short_term_parking             free_parking night_parking longitude  \
# 0             WHOLE DAY                       NO           YES   103.854
# 1             WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.885
# 2             WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.845
# 3               7AM-7PM                       NO            NO   103.835
# 4                    NO                       NO            NO   103.847
# 5             WHOLE DAY                       NO           YES    103.85
# 6           7AM-10.30PM  SUN & PH FR 7AM-10.30PM            NO   103.845
# 7                    NO                       NO            NO   103.864
# 8                    NO                       NO            NO   103.848
# 9             WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.836
# 10          7AM-10.30PM                       NO            NO   103.845
# 11          7AM-10.30PM                       NO            NO   103.835
# 12            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.846
# 13            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.848
# 14          7AM-10.30PM                       NO            NO   103.834
# 15          7AM-10.30PM                       NO            NO   103.857
# 16          7AM-10.30PM                       NO            NO   103.853
# 17            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.847
# 18          7AM-10.30PM                       NO            NO   103.853
# 19            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.851
# 20            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.842
# 21            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.842
# 22            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.851
# 23                   NO                       NO            NO   103.783
# 24            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.784
# 25                   NO                       NO            NO   103.781
# 26            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.782
# 27            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.784
# 28                   NO                       NO            NO   103.786
# 29            WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.785
# ...                 ...                      ...           ...       ...
# 2036        7AM-10.30PM  SUN & PH FR 7AM-10.30PM            NO   103.832
# 2037        7AM-10.30PM  SUN & PH FR 7AM-10.30PM            NO   103.847
# 2038          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.846
# 2039          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.845
# 2040          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.846
# 2041          WHOLE DAY                       NO           YES   103.837
# 2042        7AM-10.30PM                       NO            NO   103.837
# 2043            7AM-7PM                       NO            NO   103.846
# 2044        7AM-10.30PM                       NO            NO   103.832
# 2045          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.849
# 2046        7AM-10.30PM  SUN & PH FR 7AM-10.30PM            NO   103.834
# 2047          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.848
# 2048          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.848
# 2049          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.844
# 2050          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.845
# 2051          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.845
# 2052          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.842
# 2053          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.842
# 2054        7AM-10.30PM                       NO            NO   103.841
# 2055          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.845
# 2056          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.844
# 2057          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.827
# 2058          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES    103.84
# 2059          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.841
# 2060          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.841
# 2061          WHOLE DAY                       NO           YES   103.842
# 2062          WHOLE DAY                       NO           YES   103.842
# 2063          WHOLE DAY                       NO           YES   103.843
# 2064          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.831
# 2065          WHOLE DAY  SUN & PH FR 7AM-10.30PM           YES   103.834
#
#      latitude
# 0     1.30106
# 1       1.321
# 2     1.32828
# 3     1.36909
# 4     1.36612
# 5     1.37244
# 6     1.37484
# 7     1.37668
# 8      1.3836
# 9     1.37035
# 10    1.36554
# 11    1.36889
# 12     1.3647
# 13    1.36459
# 14    1.37053
# 15    1.36858
# 16    1.37218
# 17    1.36992
# 18    1.37146
# 19    1.37233
# 20    1.37065
# 21    1.37164
# 22    1.36407
# 23    1.30388
# 24    1.30285
# 25    1.30591
# 26    1.30474
# 27    1.30734
# 28    1.30581
# 29    1.30477
# ...       ...
# 2036  1.43111
# 2037   1.4215
# 2038  1.42274
# 2039  1.42031
# 2040  1.42292
# 2041  1.42731
# 2042  1.42545
# 2043  1.42399
# 2044  1.43254
# 2045  1.42227
# 2046  1.43252
# 2047  1.42114
# 2048  1.42009
# 2049  1.43025
# 2050  1.43165
# 2051  1.43249
# 2052  1.43267
# 2053  1.43376
# 2054  1.43646
# 2055   1.4184
# 2056  1.41601
# 2057   1.4273
# 2058  1.41486
# 2059  1.41658
# 2060  1.41476
# 2061  1.41914
# 2062  1.41963
# 2063  1.42018
# 2064  1.42944
# 2065  1.42783
#
# [2066 rows x 11 columns]

# %%
r.json()['latitude']
# Out:
# 1.3197295716669164

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-229-fda94563e63f> in <module>()
# ----> 1 latitude_df = pd.DataFrame(r.json()['latitude'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     352                                          copy=False)
#     353             else:
# --> 354                 raise ValueError('DataFrame constructor not properly called!')
#     355
#     356         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
r.json()
# Out:
# {'items': [{'carpark_data': [{'carpark_info': [{'lot_type': 'C',
#        'lots_available': '62',
#        'total_lots': '104'}],
#      'carpark_number': 'HE12',
#      'update_datetime': '2018-04-17T00:03:23'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '465',
#        'total_lots': '583'}],
#      'carpark_number': 'HLM',
#      'update_datetime': '2018-04-17T00:03:40'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '113',
#        'total_lots': '329'}],
#      'carpark_number': 'RHM',
#      'update_datetime': '2018-04-17T00:03:21'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '109',
#        'total_lots': '110'}],
#      'carpark_number': 'BM29',
#      'update_datetime': '2017-08-01T12:15:17'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '71',
#        'total_lots': '97'}],
#      'carpark_number': 'Q81',
#      'update_datetime': '2018-04-17T00:03:38'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '150',
#        'total_lots': '183'}],
#      'carpark_number': 'C20',
#      'update_datetime': '2018-04-17T00:03:17'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '84',
#        'total_lots': '288'}],
#      'carpark_number': 'FR3M',
#      'update_datetime': '2018-04-17T00:03:33'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '56',
#        'total_lots': '280'}],
#      'carpark_number': 'C32',
#      'update_datetime': '2018-04-17T00:03:13'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '81',
#        'total_lots': '337'}],
#      'carpark_number': 'C6',
#      'update_datetime': '2018-04-17T00:03:19'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '52',
#        'total_lots': '277'}],
#      'carpark_number': 'TG2',
#      'update_datetime': '2018-04-17T00:03:38'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '155',
#        'total_lots': '552'}],
#      'carpark_number': 'BP1',
#      'update_datetime': '2018-04-17T00:03:31'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '23',
#        'total_lots': '135'}],
#      'carpark_number': 'TG1',
#      'update_datetime': '2018-04-17T00:03:23'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '101',
#        'total_lots': '191'}],
#      'carpark_number': 'TGM2',
#      'update_datetime': '2018-04-17T00:03:23'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '36',
#        'total_lots': '140'}],
#      'carpark_number': 'TE14',
#      'update_datetime': '2018-04-17T00:03:39'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '49'}],
#      'carpark_number': 'BM3',
#      'update_datetime': '2018-04-17T00:03:18'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '57',
#        'total_lots': '612'}],
#      'carpark_number': 'BM9',
#      'update_datetime': '2018-04-17T00:03:23'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '32',
#        'total_lots': '180'}],
#      'carpark_number': 'HG44',
#      'update_datetime': '2018-04-14T00:28:35'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '72',
#        'total_lots': '83'}],
#      'carpark_number': 'HG64',
#      'update_datetime': '2018-04-14T00:28:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '72',
#        'total_lots': '334'}],
#      'carpark_number': 'PM27',
#      'update_datetime': '2018-04-17T00:05:21'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '69',
#        'total_lots': '311'}],
#      'carpark_number': 'PM28',
#      'update_datetime': '2018-04-17T00:05:50'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '55',
#        'total_lots': '225'}],
#      'carpark_number': 'TM36',
#      'update_datetime': '2018-04-17T00:05:28'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '68',
#        'total_lots': '240'}],
#      'carpark_number': 'TM37',
#      'update_datetime': '2018-04-17T00:05:21'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '9',
#        'total_lots': '367'}],
#      'carpark_number': 'T50',
#      'update_datetime': '2018-04-17T00:05:34'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '53',
#        'total_lots': '367'}],
#      'carpark_number': 'T51',
#      'update_datetime': '2018-04-17T00:05:26'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '150',
#        'total_lots': '239'}],
#      'carpark_number': 'TM43',
#      'update_datetime': '2018-04-17T00:05:42'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '6',
#        'total_lots': '39'}],
#      'carpark_number': 'T15',
#      'update_datetime': '2018-04-17T00:05:38'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '33',
#        'total_lots': '150'}],
#      'carpark_number': 'T16',
#      'update_datetime': '2018-04-17T00:05:40'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '15',
#        'total_lots': '245'}],
#      'carpark_number': 'T17',
#      'update_datetime': '2018-04-17T00:05:42'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '52',
#        'total_lots': '85'}],
#      'carpark_number': 'T18',
#      'update_datetime': '2018-04-17T00:05:38'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '15',
#        'total_lots': '213'}],
#      'carpark_number': 'B9',
#      'update_datetime': '2018-04-17T00:05:37'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '312'}],
#      'carpark_number': 'B10',
#      'update_datetime': '2018-04-17T00:05:50'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '63',
#        'total_lots': '208'}],
#      'carpark_number': 'B14',
#      'update_datetime': '2018-04-17T00:05:39'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '97',
#        'total_lots': '163'}],
#      'carpark_number': 'WCB',
#      'update_datetime': '2018-04-16T23:56:27'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '59',
#        'total_lots': '96'}],
#      'carpark_number': 'ACB',
#      'update_datetime': '2018-04-17T00:02:58'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '20',
#        'total_lots': '38'}],
#      'carpark_number': 'CY',
#      'update_datetime': '2018-04-17T00:02:58'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '408'}],
#      'carpark_number': 'AM46',
#      'update_datetime': '2018-04-17T00:05:57'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '384'}],
#      'carpark_number': 'A12',
#      'update_datetime': '2018-04-16T08:20:09'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '7',
#        'total_lots': '360'}],
#      'carpark_number': 'BE45',
#      'update_datetime': '2018-04-17T00:01:27'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '94',
#        'total_lots': '360'}],
#      'carpark_number': 'BE39',
#      'update_datetime': '2018-04-17T00:01:39'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '146',
#        'total_lots': '331'}],
#      'carpark_number': 'BE40',
#      'update_datetime': '2018-04-17T00:01:42'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '181',
#        'total_lots': '320'}],
#      'carpark_number': 'RCB',
#      'update_datetime': '2017-03-31T12:00:21'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '65'}],
#      'carpark_number': 'CR29',
#      'update_datetime': '2018-04-17T00:01:18'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '215',
#        'total_lots': '353'}],
#      'carpark_number': 'KLM',
#      'update_datetime': '2018-04-17T00:01:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '67',
#        'total_lots': '252'}],
#      'carpark_number': 'SE34',
#      'update_datetime': '2018-04-17T00:01:39'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '73',
#        'total_lots': '80'}],
#      'carpark_number': 'KB7',
#      'update_datetime': '2018-04-17T00:01:31'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '33',
#        'total_lots': '190'}],
#      'carpark_number': 'SE31',
#      'update_datetime': '2018-04-16T07:03:39'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '10',
#        'total_lots': '15'}],
#      'carpark_number': 'J56',
#      'update_datetime': '2018-04-17T00:00:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '325',
#        'total_lots': '369'}],
#      'carpark_number': 'J57',
#      'update_datetime': '2018-04-17T00:00:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '12',
#        'total_lots': '13'}],
#      'carpark_number': 'J57L',
#      'update_datetime': '2018-04-17T00:00:24'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '13',
#        'total_lots': '140'}],
#      'carpark_number': 'J33',
#      'update_datetime': '2018-04-17T00:00:17'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '145',
#        'total_lots': '315'}],
#      'carpark_number': 'J34',
#      'update_datetime': '2018-04-17T00:00:36'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '194',
#        'total_lots': '703'}],
#      'carpark_number': 'BL8',
#      'update_datetime': '2018-04-17T00:00:37'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '530'}],
#      'carpark_number': 'J36',
#      'update_datetime': '2018-04-17T00:00:11'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '117',
#        'total_lots': '189'}],
#      'carpark_number': 'J54',
#      'update_datetime': '2018-04-17T00:00:37'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '83',
#        'total_lots': '137'}],
#      'carpark_number': 'J55',
#      'update_datetime': '2018-04-17T00:00:37'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '54',
#        'total_lots': '393'}],
#      'carpark_number': 'J43',
#      'update_datetime': '2018-04-17T00:00:24'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '34',
#        'total_lots': '101'}],
#      'carpark_number': 'J46',
#      'update_datetime': '2018-04-17T00:00:33'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '24',
#        'total_lots': '235'}],
#      'carpark_number': 'KB1',
#      'update_datetime': '2018-04-17T00:01:32'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '452',
#        'total_lots': '688'}],
#      'carpark_number': 'GBM',
#      'update_datetime': '2018-04-17T00:01:27'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '16',
#        'total_lots': '171'}],
#      'carpark_number': 'SE14',
#      'update_datetime': '2018-04-17T00:01:32'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '427',
#        'total_lots': '584'}],
#      'carpark_number': 'SE50',
#      'update_datetime': '2018-04-17T00:01:31'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '48',
#        'total_lots': '240'}],
#      'carpark_number': 'J40',
#      'update_datetime': '2018-04-17T00:00:35'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '133',
#        'total_lots': '342'}],
#      'carpark_number': 'JM1',
#      'update_datetime': '2018-04-17T00:00:11'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '123',
#        'total_lots': '213'}],
#      'carpark_number': 'J32',
#      'update_datetime': '2018-04-17T00:00:13'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '196',
#        'total_lots': '370'}],
#      'carpark_number': 'A11',
#      'update_datetime': '2018-04-17T00:01:31'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '39',
#        'total_lots': '399'}],
#      'carpark_number': 'TR1',
#      'update_datetime': '2018-04-17T00:01:18'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '158',
#        'total_lots': '344'}],
#      'carpark_number': 'JBM',
#      'update_datetime': '2018-04-17T00:03:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '33'}],
#      'carpark_number': 'TE2',
#      'update_datetime': '2018-04-17T00:03:24'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '16',
#        'total_lots': '91'}],
#      'carpark_number': 'CR31',
#      'update_datetime': '2018-04-17T00:01:24'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '83',
#        'total_lots': '340'}],
#      'carpark_number': 'J1',
#      'update_datetime': '2018-04-17T00:00:12'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '164',
#        'total_lots': '300'}],
#      'carpark_number': 'J2',
#      'update_datetime': '2018-04-17T00:00:29'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '104',
#        'total_lots': '304'}],
#      'carpark_number': 'J3',
#      'update_datetime': '2018-04-17T00:00:34'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '143',
#        'total_lots': '1040'}],
#      'carpark_number': 'T37',
#      'update_datetime': '2018-04-17T00:05:21'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '47',
#        'total_lots': '170'}],
#      'carpark_number': 'KB3',
#      'update_datetime': '2018-04-17T00:01:21'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '104',
#        'total_lots': '230'}],
#      'carpark_number': 'KBM',
#      'update_datetime': '2018-04-17T00:01:36'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '115',
#        'total_lots': '344'}],
#      'carpark_number': 'J4',
#      'update_datetime': '2018-04-17T00:00:22'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '170',
#        'total_lots': '390'}],
#      'carpark_number': 'TGM1',
#      'update_datetime': '2018-04-17T00:03:38'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '54',
#        'total_lots': '213'}],
#      'carpark_number': 'TG3',
#      'update_datetime': '2018-04-17T00:03:16'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '20',
#        'total_lots': '208'}],
#      'carpark_number': 'TG6',
#      'update_datetime': '2018-04-17T00:03:11'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '56',
#        'total_lots': '369'}],
#      'carpark_number': 'TG7',
#      'update_datetime': '2018-04-17T00:03:21'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '35',
#        'total_lots': '100'}],
#      'carpark_number': 'CR30',
#      'update_datetime': '2018-04-17T00:01:24'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '40',
#        'total_lots': '160'}],
#      'carpark_number': 'RCM',
#      'update_datetime': '2018-04-17T00:01:38'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '109',
#        'total_lots': '298'}],
#      'carpark_number': 'EPM',
#      'update_datetime': '2018-04-17T00:03:12'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '126',
#        'total_lots': '543'}],
#      'carpark_number': 'TGM3',
#      'update_datetime': '2018-04-17T00:03:19'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '31',
#        'total_lots': '67'}],
#      'carpark_number': 'KB14',
#      'update_datetime': '2018-04-17T00:01:37'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '146',
#        'total_lots': '350'}],
#      'carpark_number': 'J41',
#      'update_datetime': '2018-04-17T00:00:15'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '159',
#        'total_lots': '245'}],
#      'carpark_number': 'JBM2',
#      'update_datetime': '2018-04-17T00:03:16'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '9',
#        'total_lots': '256'}],
#      'carpark_number': 'J39',
#      'update_datetime': '2018-04-17T00:00:37'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '262',
#        'total_lots': '677'}],
#      'carpark_number': 'J52',
#      'update_datetime': '2018-04-17T00:00:25'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '338',
#        'total_lots': '633'}],
#      'carpark_number': 'J51',
#      'update_datetime': '2018-04-17T00:00:37'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '57',
#        'total_lots': '217'}],
#      'carpark_number': 'J53',
#      'update_datetime': '2018-04-17T00:00:30'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '148',
#        'total_lots': '909'}],
#      'carpark_number': 'T19',
#      'update_datetime': '2018-04-17T00:05:23'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '138',
#        'total_lots': '504'}],
#      'carpark_number': 'J49',
#      'update_datetime': '2018-04-17T00:00:35'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '233',
#        'total_lots': '712'}],
#      'carpark_number': 'J27',
#      'update_datetime': '2018-04-17T00:00:34'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '1',
#        'total_lots': '45'}],
#      'carpark_number': 'TB14',
#      'update_datetime': '2018-04-17T00:03:22'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '147',
#        'total_lots': '650'}],
#      'carpark_number': 'U19',
#      'update_datetime': '2018-04-16T23:57:30'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '33',
#        'total_lots': '97'}],
#      'carpark_number': 'U6',
#      'update_datetime': '2018-04-16T23:57:23'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '80',
#        'total_lots': '166'}],
#      'carpark_number': 'U45',
#      'update_datetime': '2018-04-16T23:57:29'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '156',
#        'total_lots': '177'}],
#      'carpark_number': 'BBM7',
#      'update_datetime': '2018-04-16T23:57:25'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '68',
#        'total_lots': '455'}],
#      'carpark_number': 'BE12',
#      'update_datetime': '2018-04-17T00:01:38'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '74',
#        'total_lots': '478'}],
#      'carpark_number': 'HG41',
#      'update_datetime': '2018-04-17T00:05:39'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '102',
#        'total_lots': '495'}],
#      'carpark_number': 'HG43',
#      'update_datetime': '2018-04-17T00:05:44'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '318'}],
#      'carpark_number': 'MN1',
#      'update_datetime': '2018-04-17T00:01:35'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '225',
#        'total_lots': '363'}],
#      'carpark_number': 'MNRM',
#      'update_datetime': '2018-04-17T00:01:39'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '96',
#        'total_lots': '317'}],
#      'carpark_number': 'MN2',
#      'update_datetime': '2018-04-17T00:01:43'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '201',
#        'total_lots': '449'}],
#      'carpark_number': 'C7',
#      'update_datetime': '2018-04-16T23:57:03'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '49',
#        'total_lots': '54'}],
#      'carpark_number': 'C17',
#      'update_datetime': '2018-04-16T23:56:48'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '487',
#        'total_lots': '551'}],
#      'carpark_number': 'C20M',
#      'update_datetime': '2018-04-16T23:56:54'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '7',
#        'total_lots': '222'}],
#      'carpark_number': 'T41',
#      'update_datetime': '2018-04-17T00:05:35'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '7',
#        'total_lots': '89'}],
#      'carpark_number': 'T42',
#      'update_datetime': '2018-04-17T00:05:50'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '221',
#        'total_lots': '259'}],
#      'carpark_number': 'TM42',
#      'update_datetime': '2018-04-17T00:05:48'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '308',
#        'total_lots': '718'}],
#      'carpark_number': 'J48',
#      'update_datetime': '2018-04-17T00:00:35'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '54',
#        'total_lots': '1000'}],
#      'carpark_number': 'BH1',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '40',
#        'total_lots': '1000'}],
#      'carpark_number': 'BH2',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '148',
#        'total_lots': '1000'}],
#      'carpark_number': 'BKE7',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '29',
#        'total_lots': '1000'}],
#      'carpark_number': 'BR5',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '154',
#        'total_lots': '1000'}],
#      'carpark_number': 'BRM3',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '30',
#        'total_lots': '1000'}],
#      'carpark_number': 'BRM4',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '40',
#        'total_lots': '1000'}],
#      'carpark_number': 'M16',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '1000'}],
#      'carpark_number': 'M20',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '16',
#        'total_lots': '1000'}],
#      'carpark_number': 'M35',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '1000'}],
#      'carpark_number': 'M36',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '1000'}],
#      'carpark_number': 'M37',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '3',
#        'total_lots': '1000'}],
#      'carpark_number': 'M38',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '90',
#        'total_lots': '1000'}],
#      'carpark_number': 'MM3',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '44',
#        'total_lots': '1000'}],
#      'carpark_number': 'MP12',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '132',
#        'total_lots': '1000'}],
#      'carpark_number': 'MP13',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '201',
#        'total_lots': '1000'}],
#      'carpark_number': 'MP1M',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '53',
#        'total_lots': '1000'}],
#      'carpark_number': 'PP1',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '40',
#        'total_lots': '1000'}],
#      'carpark_number': 'PP2',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '65',
#        'total_lots': '1000'}],
#      'carpark_number': 'PP3',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '1000'}],
#      'carpark_number': 'PP4',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '59',
#        'total_lots': '1000'}],
#      'carpark_number': 'PP5',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '19',
#        'total_lots': '1000'}],
#      'carpark_number': 'TP10',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '10',
#        'total_lots': '1000'}],
#      'carpark_number': 'TP14',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '578',
#        'total_lots': '1000'}],
#      'carpark_number': 'TP16',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '65',
#        'total_lots': '1000'}],
#      'carpark_number': 'TP17',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '274',
#        'total_lots': '1000'}],
#      'carpark_number': 'TP18',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '1000'}],
#      'carpark_number': 'TP2',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '77',
#        'total_lots': '1000'}],
#      'carpark_number': 'TPMG',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '1000'}],
#      'carpark_number': 'TP36',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '30',
#        'total_lots': '1000'}],
#      'carpark_number': 'TPM4',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '98',
#        'total_lots': '1000'}],
#      'carpark_number': 'TPM5',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '80',
#        'total_lots': '1000'}],
#      'carpark_number': 'TPM6',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '111',
#        'total_lots': '1000'}],
#      'carpark_number': 'TP27',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '90',
#        'total_lots': '1000'}],
#      'carpark_number': 'TPMN',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '29',
#        'total_lots': '1000'}],
#      'carpark_number': 'TPMP',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '1',
#        'total_lots': '1000'}],
#      'carpark_number': 'WDB1',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '316',
#        'total_lots': '1000'}],
#      'carpark_number': 'Y23',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '22',
#        'total_lots': '1000'}],
#      'carpark_number': 'Y24',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '7',
#        'total_lots': '1000'}],
#      'carpark_number': 'Y56',
#      'update_datetime': '2018-04-17T00:02:20'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '160',
#        'total_lots': '1000'}],
#      'carpark_number': 'BBM1',
#      'update_datetime': '2018-04-17T00:04:03'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '1000'}],
#      'carpark_number': 'BBM8',
#      'update_datetime': '2018-04-17T00:04:03'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '1000'}],
#      'carpark_number': 'BJ10',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '1000'}],
#      'carpark_number': 'BJ11',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '28',
#        'total_lots': '1000'}],
#      'carpark_number': 'BJ12',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '42',
#        'total_lots': '1000'}],
#      'carpark_number': 'BJ17',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '1000'}],
#      'carpark_number': 'BJ18',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '269',
#        'total_lots': '1000'}],
#      'carpark_number': 'BJ28',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '89',
#        'total_lots': '1000'}],
#      'carpark_number': 'BJ3',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '231',
#        'total_lots': '1000'}],
#      'carpark_number': 'BJ33',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '219',
#        'total_lots': '1000'}],
#      'carpark_number': 'BJ42',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '49',
#        'total_lots': '1000'}],
#      'carpark_number': 'BJ45',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '18',
#        'total_lots': '1000'}],
#      'carpark_number': 'CK21',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '18',
#        'total_lots': '1000'}],
#      'carpark_number': 'U48',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '10',
#        'total_lots': '1000'}],
#      'carpark_number': 'U5',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '254',
#        'total_lots': '493'}],
#      'carpark_number': 'JM14',
#      'update_datetime': '2018-04-17T00:01:12'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '123',
#        'total_lots': '471'}],
#      'carpark_number': 'JM12',
#      'update_datetime': '2018-04-17T00:02:41'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '1000'}],
#      'carpark_number': 'W39',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '140',
#        'total_lots': '735'}],
#      'carpark_number': 'PL67',
#      'update_datetime': '2018-04-17T00:03:39'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '19',
#        'total_lots': '1000'}],
#      'carpark_number': 'W2',
#      'update_datetime': '2017-12-04T10:54:50'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '53',
#        'total_lots': '1000'}],
#      'carpark_number': 'W1',
#      'update_datetime': '2017-12-04T10:54:50'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '1',
#        'total_lots': '1000'}],
#      'carpark_number': 'U9',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '10',
#        'total_lots': '1000'}],
#      'carpark_number': 'U26',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '62',
#        'total_lots': '1000'}],
#      'carpark_number': 'U25',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '18',
#        'total_lots': '1000'}],
#      'carpark_number': 'U24T',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '16',
#        'total_lots': '1000'}],
#      'carpark_number': 'U24',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '30',
#        'total_lots': '1000'}],
#      'carpark_number': 'U23',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '61',
#        'total_lots': '1000'}],
#      'carpark_number': 'U22',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '56',
#        'total_lots': '1000'}],
#      'carpark_number': 'U21',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '1000'}],
#      'carpark_number': 'U2',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '119',
#        'total_lots': '355'}],
#      'carpark_number': 'J45',
#      'update_datetime': '2018-04-17T00:00:13'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '129'}],
#      'carpark_number': 'TM25',
#      'update_datetime': '2018-04-17T00:05:44'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '17',
#        'total_lots': '127'}],
#      'carpark_number': 'TM26',
#      'update_datetime': '2018-04-17T00:05:34'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '153',
#        'total_lots': '239'}],
#      'carpark_number': 'TM27',
#      'update_datetime': '2018-04-17T00:05:33'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '52',
#        'total_lots': '266'}],
#      'carpark_number': 'J37',
#      'update_datetime': '2018-04-17T00:00:24'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '23',
#        'total_lots': '60'}],
#      'carpark_number': 'BM1',
#      'update_datetime': '2018-04-16T23:55:32'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '28',
#        'total_lots': '53'}],
#      'carpark_number': 'BM2',
#      'update_datetime': '2018-04-16T23:55:32'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '319',
#        'total_lots': '460'}],
#      'carpark_number': 'BM26',
#      'update_datetime': '2018-04-16T23:55:34'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '53'}],
#      'carpark_number': 'BWM',
#      'update_datetime': '2018-04-16T23:55:34'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '41',
#        'total_lots': '156'}],
#      'carpark_number': 'TBMT',
#      'update_datetime': '2018-04-16T23:56:03'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '319',
#        'total_lots': '383'}],
#      'carpark_number': 'TPM',
#      'update_datetime': '2018-04-16T23:55:33'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '163',
#        'total_lots': '334'}],
#      'carpark_number': 'U29',
#      'update_datetime': '2018-04-16T23:57:34'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '14',
#        'total_lots': '19'}],
#      'carpark_number': 'U27',
#      'update_datetime': '2018-04-16T23:57:42'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '129',
#        'total_lots': '300'}],
#      'carpark_number': 'U18',
#      'update_datetime': '2018-04-16T23:57:26'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '26',
#        'total_lots': '135'}],
#      'carpark_number': 'U30',
#      'update_datetime': '2018-04-16T23:57:34'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '25'}],
#      'carpark_number': 'EPML',
#      'update_datetime': '2015-12-30T10:38:36'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '92',
#        'total_lots': '301'}],
#      'carpark_number': 'TE25',
#      'update_datetime': '2018-04-17T00:03:36'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '18',
#        'total_lots': '146'}],
#      'carpark_number': 'TE3',
#      'update_datetime': '2018-04-17T00:03:15'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '2',
#        'total_lots': '34'}],
#      'carpark_number': 'TE4',
#      'update_datetime': '2018-04-17T00:03:15'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '21',
#        'total_lots': '23'}],
#      'carpark_number': 'U28',
#      'update_datetime': '2018-04-16T23:57:21'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '6',
#        'total_lots': '57'}],
#      'carpark_number': 'A15',
#      'update_datetime': '2018-04-16T08:41:38'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '9',
#        'total_lots': '49'}],
#      'carpark_number': 'BM28',
#      'update_datetime': '2018-04-16T23:56:26'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '37',
#        'total_lots': '44'}],
#      'carpark_number': 'BM30',
#      'update_datetime': '2018-04-16T23:56:03'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '112',
#        'total_lots': '292'}],
#      'carpark_number': 'BTM',
#      'update_datetime': '2018-04-16T23:56:26'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '292',
#        'total_lots': '494'}],
#      'carpark_number': 'BTM2',
#      'update_datetime': '2018-04-16T23:56:26'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '117',
#        'total_lots': '334'}],
#      'carpark_number': 'SAM2',
#      'update_datetime': '2018-04-16T23:56:25'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '104',
#        'total_lots': '251'}],
#      'carpark_number': 'TBM2',
#      'update_datetime': '2018-04-16T23:56:27'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '90',
#        'total_lots': '242'}],
#      'carpark_number': 'TJ34',
#      'update_datetime': '2018-04-17T00:03:32'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '35',
#        'total_lots': '246'}],
#      'carpark_number': 'U31',
#      'update_datetime': '2018-04-16T23:57:24'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '16',
#        'total_lots': '399'}],
#      'carpark_number': 'BL13',
#      'update_datetime': '2018-04-17T00:03:18'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '88',
#        'total_lots': '246'}],
#      'carpark_number': 'HG10',
#      'update_datetime': '2018-04-17T00:04:07'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '13',
#        'total_lots': '1000'}],
#      'carpark_number': 'W3',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '72',
#        'total_lots': '227'}],
#      'carpark_number': 'BJ65',
#      'update_datetime': '2018-04-17T00:01:47'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '13',
#        'total_lots': '68'}],
#      'carpark_number': 'CK19',
#      'update_datetime': '2018-04-17T00:02:08'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '4',
#        'total_lots': '16'}],
#      'carpark_number': 'CK4',
#      'update_datetime': '2018-04-17T00:02:06'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '261',
#        'total_lots': '922'}],
#      'carpark_number': 'CK42',
#      'update_datetime': '2018-04-17T00:01:46'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '124',
#        'total_lots': '306'}],
#      'carpark_number': 'CK7',
#      'update_datetime': '2018-04-17T00:02:07'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '19',
#        'total_lots': '108'}],
#      'carpark_number': 'TW1',
#      'update_datetime': '2018-04-17T00:01:51'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '138',
#        'total_lots': '355'}],
#      'carpark_number': 'TW2',
#      'update_datetime': '2018-04-17T00:02:02'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '139',
#        'total_lots': '338'}],
#      'carpark_number': 'TW3',
#      'update_datetime': '2018-04-17T00:01:48'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '286',
#        'total_lots': '353'}],
#      'carpark_number': 'BL18M',
#      'update_datetime': '2016-02-04T18:15:45'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '229',
#        'total_lots': '342'}],
#      'carpark_number': 'B16',
#      'update_datetime': '2018-04-17T00:04:03'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '203',
#        'total_lots': '383'}],
#      'carpark_number': 'B17',
#      'update_datetime': '2018-04-17T00:04:03'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '183',
#        'total_lots': '413'}],
#      'carpark_number': 'B20',
#      'update_datetime': '2018-04-17T00:04:03'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '53',
#        'total_lots': '120'}],
#      'carpark_number': 'B42',
#      'update_datetime': '2018-04-17T00:04:03'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '45',
#        'total_lots': '74'}],
#      'carpark_number': 'B45',
#      'update_datetime': '2018-04-17T00:03:11'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '449',
#        'total_lots': '513'}],
#      'carpark_number': 'B6',
#      'update_datetime': '2018-04-17T00:03:53'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '77',
#        'total_lots': '120'}],
#      'carpark_number': 'B63',
#      'update_datetime': '2018-04-17T00:03:53'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '258',
#        'total_lots': '739'}],
#      'carpark_number': 'B65',
#      'update_datetime': '2018-04-17T00:03:25'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '41',
#        'total_lots': '86'}],
#      'carpark_number': 'B7',
#      'update_datetime': '2018-04-17T00:03:47'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '27',
#        'total_lots': '39'}],
#      'carpark_number': 'B70',
#      'update_datetime': '2018-04-17T00:03:43'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '133',
#        'total_lots': '253'}],
#      'carpark_number': 'B71',
#      'update_datetime': '2018-04-17T00:03:22'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '126'}],
#      'carpark_number': 'B7A',
#      'update_datetime': '2018-04-17T00:03:55'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '65',
#        'total_lots': '105'}],
#      'carpark_number': 'B8',
#      'update_datetime': '2018-04-17T00:03:43'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '235',
#        'total_lots': '244'}],
#      'carpark_number': 'B80',
#      'update_datetime': '2018-04-17T00:03:53'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '547',
#        'total_lots': '551'}],
#      'carpark_number': 'B84',
#      'update_datetime': '2018-04-17T00:03:55'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '120',
#        'total_lots': '120'}],
#      'carpark_number': 'B88M',
#      'update_datetime': '2015-03-03T05:02:19'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '75',
#        'total_lots': '75'}],
#      'carpark_number': 'B90',
#      'update_datetime': '2015-03-03T05:02:19'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '75',
#        'total_lots': '75'}],
#      'carpark_number': 'B90M',
#      'update_datetime': '2015-03-03T05:02:19'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '37',
#        'total_lots': '114'}],
#      'carpark_number': 'CC5',
#      'update_datetime': '2018-04-17T00:03:22'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '22',
#        'total_lots': '37'}],
#      'carpark_number': 'CC6',
#      'update_datetime': '2018-04-17T00:03:22'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '104',
#        'total_lots': '341'}],
#      'carpark_number': 'B30',
#      'update_datetime': '2018-04-17T00:03:29'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '229',
#        'total_lots': '414'}],
#      'carpark_number': 'B31',
#      'update_datetime': '2018-04-17T00:03:30'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '20'}],
#      'carpark_number': 'TJ28',
#      'update_datetime': '2018-04-17T00:03:25'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '230',
#        'total_lots': '458'}],
#      'carpark_number': 'TJ31',
#      'update_datetime': '2018-04-16T23:59:43'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '232',
#        'total_lots': '384'}],
#      'carpark_number': 'TJ37',
#      'update_datetime': '2018-04-17T00:01:14'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '820',
#        'total_lots': '842'}],
#      'carpark_number': 'TJSF',
#      'update_datetime': '2018-04-16T23:59:43'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '68',
#        'total_lots': '115'}],
#      'carpark_number': 'AM16',
#      'update_datetime': '2018-04-17T00:06:03'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '91'}],
#      'carpark_number': 'AM32',
#      'update_datetime': '2018-04-17T00:06:18'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '75',
#        'total_lots': '464'}],
#      'carpark_number': 'BJ2',
#      'update_datetime': '2018-04-17T00:02:11'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '250',
#        'total_lots': '590'}],
#      'carpark_number': 'CK48',
#      'update_datetime': '2018-04-17T00:02:02'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '340',
#        'total_lots': '562'}],
#      'carpark_number': 'BE8',
#      'update_datetime': '2018-04-17T00:03:51'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '188',
#        'total_lots': '192'}],
#      'carpark_number': 'SE11',
#      'update_datetime': '2018-04-17T00:03:50'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '525',
#        'total_lots': '554'}],
#      'carpark_number': 'SE20',
#      'update_datetime': '2018-04-17T00:03:42'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '141',
#        'total_lots': '192'}],
#      'carpark_number': 'SE21',
#      'update_datetime': '2018-04-17T00:03:50'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '12',
#        'total_lots': '29'}],
#      'carpark_number': 'SE22',
#      'update_datetime': '2018-04-17T00:03:50'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '7',
#        'total_lots': '20'}],
#      'carpark_number': 'SE23',
#      'update_datetime': '2018-04-17T00:03:51'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '137',
#        'total_lots': '163'}],
#      'carpark_number': 'SE24',
#      'update_datetime': '2018-04-17T00:03:44'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '294',
#        'total_lots': '340'}],
#      'carpark_number': 'SE53',
#      'update_datetime': '2018-04-17T00:04:01'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '19'}],
#      'carpark_number': 'SM9A',
#      'update_datetime': '2016-04-25T17:56:45'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '2',
#        'total_lots': '28'}],
#      'carpark_number': 'SM9B',
#      'update_datetime': '2016-04-25T17:56:46'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '13',
#        'total_lots': '88'}],
#      'carpark_number': 'FR4M',
#      'update_datetime': '2018-04-16T23:56:44'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '21',
#        'total_lots': '90'}],
#      'carpark_number': 'BJ31',
#      'update_datetime': '2018-04-17T00:02:10'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '678',
#        'total_lots': '960'}],
#      'carpark_number': 'BJ32',
#      'update_datetime': '2018-04-17T00:01:55'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '6',
#        'total_lots': '142'}],
#      'carpark_number': 'BJ34',
#      'update_datetime': '2018-04-17T00:01:48'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '11',
#        'total_lots': '144'}],
#      'carpark_number': 'BJ35',
#      'update_datetime': '2018-04-17T00:01:54'},
# ...
#        'lots_available': '151',
#        'total_lots': '183'}],
#      'carpark_number': 'TPME',
#      'update_datetime': '2018-04-17T00:03:46'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '230',
#        'total_lots': '460'}],
#      'carpark_number': 'TPMF',
#      'update_datetime': '2018-04-17T00:03:46'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '199',
#        'total_lots': '246'}],
#      'carpark_number': 'TPMH',
#      'update_datetime': '2018-04-17T00:03:25'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '409',
#        'total_lots': '656'}],
#      'carpark_number': 'TPMJ',
#      'update_datetime': '2018-04-17T00:03:46'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '168',
#        'total_lots': '248'}],
#      'carpark_number': 'TPMK',
#      'update_datetime': '2018-04-17T00:03:26'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '131',
#        'total_lots': '288'}],
#      'carpark_number': 'TPML',
#      'update_datetime': '2018-04-17T00:03:46'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '143',
#        'total_lots': '329'}],
#      'carpark_number': 'TPMM',
#      'update_datetime': '2018-04-17T00:03:46'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '505',
#        'total_lots': '777'}],
#      'carpark_number': 'SK24',
#      'update_datetime': '2018-04-17T00:02:45'},
#     {'carpark_info': [{'lot_type': 'Y',
#        'lots_available': '200',
#        'total_lots': '181'}],
#      'carpark_number': 'SK24',
#      'update_datetime': '2016-02-19T11:19:28'},
#     {'carpark_info': [{'lot_type': 'H',
#        'lots_available': '200',
#        'total_lots': '181'}],
#      'carpark_number': 'SK24',
#      'update_datetime': '2016-02-19T11:19:29'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '118',
#        'total_lots': '246'}],
#      'carpark_number': 'HG17',
#      'update_datetime': '2018-04-17T00:04:07'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '531',
#        'total_lots': '839'}],
#      'carpark_number': 'HG75',
#      'update_datetime': '2018-04-17T00:03:49'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '195',
#        'total_lots': '404'}],
#      'carpark_number': 'HG86',
#      'update_datetime': '2018-04-17T00:04:01'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '707',
#        'total_lots': '1017'}],
#      'carpark_number': 'HG92',
#      'update_datetime': '2018-04-17T00:04:03'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '96',
#        'total_lots': '346'},
#       {'lot_type': 'Y', 'lots_available': '0', 'total_lots': '0'},
#       {'lot_type': 'H', 'lots_available': '0', 'total_lots': '0'}],
#      'carpark_number': 'Q86',
#      'update_datetime': '2018-04-17T00:02:59'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '1',
#        'total_lots': '18'},
#       {'lot_type': 'Y', 'lots_available': '0', 'total_lots': '155'},
#       {'lot_type': 'H', 'lots_available': '0', 'total_lots': '0'}],
#      'carpark_number': 'Q19',
#      'update_datetime': '2018-04-17T00:04:14'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '88',
#        'total_lots': '266'},
#       {'lot_type': 'Y', 'lots_available': '0', 'total_lots': '88'},
#       {'lot_type': 'H', 'lots_available': '0', 'total_lots': '0'}],
#      'carpark_number': 'MLM1',
#      'update_datetime': '2018-04-17T00:04:01'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '29',
#        'total_lots': '104'},
#       {'lot_type': 'Y', 'lots_available': '0', 'total_lots': '12'},
#       {'lot_type': 'H', 'lots_available': '0', 'total_lots': '0'}],
#      'carpark_number': 'STM1',
#      'update_datetime': '2018-04-17T00:02:35'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '124',
#        'total_lots': '220'},
#       {'lot_type': 'Y', 'lots_available': '0', 'total_lots': '52'},
#       {'lot_type': 'H', 'lots_available': '0', 'total_lots': '0'}],
#      'carpark_number': 'STM2',
#      'update_datetime': '2018-04-17T00:02:50'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '35'},
#       {'lot_type': 'Y', 'lots_available': '0', 'total_lots': '155'},
#       {'lot_type': 'H', 'lots_available': '0', 'total_lots': '0'}],
#      'carpark_number': 'STM3',
#      'update_datetime': '2018-04-17T00:02:49'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '120',
#        'total_lots': '216'},
#       {'lot_type': 'Y', 'lots_available': '0', 'total_lots': '200'},
#       {'lot_type': 'H', 'lots_available': '0', 'total_lots': '0'}],
#      'carpark_number': 'Q88',
#      'update_datetime': '2018-04-17T00:02:34'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '45',
#        'total_lots': '139'},
#       {'lot_type': 'Y', 'lots_available': '0', 'total_lots': '155'},
#       {'lot_type': 'H', 'lots_available': '0', 'total_lots': '0'}],
#      'carpark_number': 'Q8',
#      'update_datetime': '2018-04-17T00:02:51'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '119',
#        'total_lots': '275'},
#       {'lot_type': 'Y', 'lots_available': '0', 'total_lots': '155'},
#       {'lot_type': 'H', 'lots_available': '0', 'total_lots': '0'}],
#      'carpark_number': 'CDM',
#      'update_datetime': '2018-04-17T00:02:28'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '35',
#        'total_lots': '153'}],
#      'carpark_number': 'PL16',
#      'update_datetime': '2018-04-17T00:03:47'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '70',
#        'total_lots': '291'}],
#      'carpark_number': 'PL19',
#      'update_datetime': '2018-04-17T00:03:52'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '469',
#        'total_lots': '749'}],
#      'carpark_number': 'PL24',
#      'update_datetime': '2018-04-17T00:03:48'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '106',
#        'total_lots': '399'}],
#      'carpark_number': 'PL38',
#      'update_datetime': '2018-04-17T00:03:19'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '40',
#        'total_lots': '192'}],
#      'carpark_number': 'PL50',
#      'update_datetime': '2018-04-17T00:03:40'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '121',
#        'total_lots': '321'}],
#      'carpark_number': 'PL51',
#      'update_datetime': '2018-04-17T00:03:40'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '150',
#        'total_lots': '464'}],
#      'carpark_number': 'CK2',
#      'update_datetime': '2018-04-17T00:01:56'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '39',
#        'total_lots': '84'}],
#      'carpark_number': 'A28',
#      'update_datetime': '2018-04-17T00:06:06'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '155',
#        'total_lots': '310'}],
#      'carpark_number': 'A31',
#      'update_datetime': '2018-04-17T00:06:02'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '157'}],
#      'carpark_number': 'A44',
#      'update_datetime': '2018-04-17T00:06:03'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '251'}],
#      'carpark_number': 'A27',
#      'update_datetime': '2018-04-17T00:06:07'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '109',
#        'total_lots': '353'}],
#      'carpark_number': 'A75',
#      'update_datetime': '2018-04-17T00:06:07'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '159',
#        'total_lots': '762'}],
#      'carpark_number': 'SE41',
#      'update_datetime': '2018-04-17T00:06:19'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '82',
#        'total_lots': '187'}],
#      'carpark_number': 'A2',
#      'update_datetime': '2018-04-17T00:06:01'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '89',
#        'total_lots': '234'}],
#      'carpark_number': 'A94',
#      'update_datetime': '2018-04-17T00:05:55'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '90',
#        'total_lots': '181'}],
#      'carpark_number': 'HG1D',
#      'update_datetime': '2018-04-17T00:04:06'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '1073',
#        'total_lots': '1854'}],
#      'carpark_number': 'CK54',
#      'update_datetime': '2018-04-17T00:01:50'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '35',
#        'total_lots': '120'}],
#      'carpark_number': 'HE17',
#      'update_datetime': '2018-04-16T23:56:28'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '37',
#        'total_lots': '94'}],
#      'carpark_number': 'SPS',
#      'update_datetime': '2018-04-16T23:56:24'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '203'}],
#      'carpark_number': 'TB10',
#      'update_datetime': '2018-04-16T23:56:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '90',
#        'total_lots': '152'}],
#      'carpark_number': 'TB11',
#      'update_datetime': '2018-04-16T23:56:25'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '15',
#        'total_lots': '18'}],
#      'carpark_number': 'TB22',
#      'update_datetime': '2018-04-16T23:56:03'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '4',
#        'total_lots': '107'}],
#      'carpark_number': 'TB23',
#      'update_datetime': '2018-04-16T23:56:22'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '5',
#        'total_lots': '18'}],
#      'carpark_number': 'TB28',
#      'update_datetime': '2018-04-16T23:56:19'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '0',
#        'total_lots': '46'}],
#      'carpark_number': 'TB4A',
#      'update_datetime': '2018-04-16T23:56:25'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '74',
#        'total_lots': '136'}],
#      'carpark_number': 'TB6',
#      'update_datetime': '2018-04-16T23:56:24'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '107',
#        'total_lots': '186'}],
#      'carpark_number': 'TB7',
#      'update_datetime': '2018-04-16T23:56:25'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '47',
#        'total_lots': '84'}],
#      'carpark_number': 'TB8',
#      'update_datetime': '2018-04-16T23:56:27'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '334',
#        'total_lots': '544'}],
#      'carpark_number': 'TBCM',
#      'update_datetime': '2018-04-16T23:56:25'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '54',
#        'total_lots': '95'}],
#      'carpark_number': 'TE1',
#      'update_datetime': '2018-04-16T23:56:22'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '21',
#        'total_lots': '60'}],
#      'carpark_number': 'YHS',
#      'update_datetime': '2018-04-16T23:56:26'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '206',
#        'total_lots': '704'}],
#      'carpark_number': 'JM5',
#      'update_datetime': '2018-04-17T00:02:54'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '186',
#        'total_lots': '702'}],
#      'carpark_number': 'JM6',
#      'update_datetime': '2018-04-17T00:02:55'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '681',
#        'total_lots': '691'}],
#      'carpark_number': 'JM7M',
#      'update_datetime': '2015-08-19T11:39:45'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '360',
#        'total_lots': '478'}],
#      'carpark_number': 'JM8',
#      'update_datetime': '2018-04-17T00:03:26'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '480',
#        'total_lots': '481'}],
#      'carpark_number': 'JM8M',
#      'update_datetime': '2015-08-19T11:39:45'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '6',
#        'total_lots': '417'}],
#      'carpark_number': 'JM9',
#      'update_datetime': '2018-04-16T23:59:45'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '1189',
#        'total_lots': '1194'}],
#      'carpark_number': 'JSR1',
#      'update_datetime': '2018-04-17T00:03:21'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '43',
#        'total_lots': '225'}],
#      'carpark_number': 'TJ27',
#      'update_datetime': '2018-04-17T00:02:50'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '485',
#        'total_lots': '555'}],
#      'carpark_number': 'TJ28M',
#      'update_datetime': '2016-02-04T18:35:55'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '206',
#        'total_lots': '303'}],
#      'carpark_number': 'TJ29',
#      'update_datetime': '2018-04-17T00:02:50'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '418',
#        'total_lots': '731'}],
#      'carpark_number': 'TJ30',
#      'update_datetime': '2018-04-17T00:02:57'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '272',
#        'total_lots': '288'}],
#      'carpark_number': 'TJ30S',
#      'update_datetime': '2016-02-05T15:39:25'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '134',
#        'total_lots': '544'}],
#      'carpark_number': 'TJ32',
#      'update_datetime': '2018-04-17T00:02:02'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '238',
#        'total_lots': '441'}],
#      'carpark_number': 'TJ33',
#      'update_datetime': '2018-04-17T00:03:13'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '439',
#        'total_lots': '440'}],
#      'carpark_number': 'TJ33S',
#      'update_datetime': '2015-12-24T18:04:02'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '148',
#        'total_lots': '305'}],
#      'carpark_number': 'TJ36',
#      'update_datetime': '2018-04-17T00:03:13'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '155',
#        'total_lots': '296'}],
#      'carpark_number': 'TP4A',
#      'update_datetime': '2018-04-17T00:03:46'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '265',
#        'total_lots': '302'}],
#      'carpark_number': 'CV1',
#      'update_datetime': '2018-04-17T00:02:55'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '24',
#        'total_lots': '79'}],
#      'carpark_number': 'CV3',
#      'update_datetime': '2018-04-17T00:03:17'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '179',
#        'total_lots': '454'}],
#      'carpark_number': 'PM32',
#      'update_datetime': '2018-04-17T00:03:08'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '124',
#        'total_lots': '452'}],
#      'carpark_number': 'PM33',
#      'update_datetime': '2018-04-17T00:03:08'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '163',
#        'total_lots': '442'}],
#      'carpark_number': 'PM34',
#      'update_datetime': '2018-04-17T00:03:08'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '356',
#        'total_lots': '1159'}],
#      'carpark_number': 'Y19',
#      'update_datetime': '2018-04-17T00:03:50'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '104',
#        'total_lots': '251'}],
#      'carpark_number': 'Y18',
#      'update_datetime': '2018-04-17T00:03:38'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '153',
#        'total_lots': '291'}],
#      'carpark_number': 'Y26',
#      'update_datetime': '2018-04-17T00:04:04'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '8',
#        'total_lots': '8'}],
#      'carpark_number': 'S28L',
#      'update_datetime': '2018-04-17T00:04:10'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '23',
#        'total_lots': '28'}],
#      'carpark_number': 'CV2',
#      'update_datetime': '2018-04-17T00:03:23'},
#     {'carpark_info': [{'lot_type': 'C',
#        'lots_available': '16',
#        'total_lots': '21'}],
#      'carpark_number': 'S30L',
#      'update_datetime': '2018-04-17T00:02:31'},
#     ...],
#    'timestamp': '2018-04-17T00:04:28+08:00'}]}

# %%
#metadata = r.json()['metadata']

# %%
pd.date_range(date, periods=2, freq='30min')
# Out:
# DatetimeIndex(['2018-04-17 00:05:00', '2018-04-17 00:35:00'], dtype='datetime64[ns]', freq='30T')

# %% [markdown]
# ## Carpark Availability - 30min interval

# %%
# Get carpark availability at 30-min intervals on a specific date
carpark_df = pd.DataFrame(columns=['lot_type', 'total_lots', 'lots_available', 'timestamp (SGT)'])
for dt in tqdm(pd.date_range(datetime,  periods=(24*(60/30)+1), freq='30min')):  # I remember this was a wet day
    r = requests.get('https://api.data.gov.sg/v1/transport/carpark-availability',
                     params={'date_time': dt.strftime('%Y-%m-%dT%H:%M:%S')})
    try:
        temp_df = pd.DataFrame(r.json()['items'][0]['carpark_data'])
    except ValueError:
        print('No data JSONDecodeError {}'.format(dt))
        continue
    except KeyError:
        print('No items KeyError {}'.format(dt))
        continue
    #temp_df = temp_df.rename(columns={'lots_available': 'lots_available'})
    temp_df['timestamp (SGT)'] = pd.to_datetime(r.json()['items'][0]['timestamp'].split('+')[0])
    carpark_df = carpark_df.append(temp_df, ignore_index=True)
carpark_df.head()
# Out:
#  84%|████████▎ | 41/49 [00:43<00:08,  1.07s/it]
# No items KeyError 2018-01-08 20:35:00
#  94%|█████████▍| 46/49 [01:35<00:06,  2.07s/it]
# No items KeyError 2018-01-08 23:05:00
# 100%|██████████| 49/49 [02:00<00:00,  2.47s/it]
#                                         carpark_info carpark_number lot_type  \
# 0  [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12      NaN
# 1  [{'total_lots': '583', 'lot_type': 'C', 'lots_...            HLM      NaN
# 2  [{'total_lots': '329', 'lot_type': 'C', 'lots_...            RHM      NaN
# 3  [{'total_lots': '110', 'lot_type': 'C', 'lots_...           BM29      NaN
# 4  [{'total_lots': '97', 'lot_type': 'C', 'lots_a...            Q81      NaN
#
#   lots_available     timestamp (SGT) total_lots      update_datetime
# 0            NaN 2018-01-08 00:04:27        NaN  2018-01-08T00:03:19
# 1            NaN 2018-01-08 00:04:27        NaN  2018-01-08T00:03:12
# 2            NaN 2018-01-08 00:04:27        NaN  2018-01-08T00:03:07
# 3            NaN 2018-01-08 00:04:27        NaN  2017-08-01T12:15:17
# 4            NaN 2018-01-08 00:04:27        NaN  2018-01-08T00:03:27

# %%
pd.date_range(date,  periods=(24*(60/30)+1), freq='30min')
# Out:
# DatetimeIndex(['2018-04-17 00:00:00', '2018-04-17 00:30:00',
#                '2018-04-17 01:00:00', '2018-04-17 01:30:00',
#                '2018-04-17 02:00:00', '2018-04-17 02:30:00',
#                '2018-04-17 03:00:00', '2018-04-17 03:30:00',
#                '2018-04-17 04:00:00', '2018-04-17 04:30:00',
#                '2018-04-17 05:00:00', '2018-04-17 05:30:00',
#                '2018-04-17 06:00:00', '2018-04-17 06:30:00',
#                '2018-04-17 07:00:00', '2018-04-17 07:30:00',
#                '2018-04-17 08:00:00', '2018-04-17 08:30:00',
#                '2018-04-17 09:00:00', '2018-04-17 09:30:00',
#                '2018-04-17 10:00:00', '2018-04-17 10:30:00',
#                '2018-04-17 11:00:00', '2018-04-17 11:30:00',
#                '2018-04-17 12:00:00', '2018-04-17 12:30:00',
#                '2018-04-17 13:00:00', '2018-04-17 13:30:00',
#                '2018-04-17 14:00:00', '2018-04-17 14:30:00',
#                '2018-04-17 15:00:00', '2018-04-17 15:30:00',
#                '2018-04-17 16:00:00', '2018-04-17 16:30:00',
#                '2018-04-17 17:00:00', '2018-04-17 17:30:00',
#                '2018-04-17 18:00:00', '2018-04-17 18:30:00',
#                '2018-04-17 19:00:00', '2018-04-17 19:30:00',
#                '2018-04-17 20:00:00', '2018-04-17 20:30:00',
#                '2018-04-17 21:00:00', '2018-04-17 21:30:00',
#                '2018-04-17 22:00:00', '2018-04-17 22:30:00',
#                '2018-04-17 23:00:00', '2018-04-17 23:30:00',
#                '2018-04-18 00:00:00'],
#               dtype='datetime64[ns]', freq='30T')

# %% [markdown]
# ## Carpark Availability - 5min interval

# %%
# Get carpark availability at 5-min intervals on a specific date
carpark_df = pd.DataFrame(columns=['lot_type', 'total_lots', 'lots_available', 'timestamp (SGT)'])
for dt in pd.date_range(datetime,  periods=(24*(60/5)+1), freq='5min'):  # I remember this was a wet day
    r = requests.get('https://api.data.gov.sg/v1/transport/carpark-availability',
                     params={'date_time': dt.strftime('%Y-%m-%dT%H:%M:%S')})
    try:
        temp_df = pd.DataFrame(r.json()['items'][0]['carpark_data'])
        #temp_df = temp_df.rename(columns={'lots_available': 'lots_available'})
    except ValueError:
        print('No data JSONDecodeError {}'.format(dt))
        continue
    except KeyError:
        print('No items KeyError {}'.format(dt))
        continue
    temp_df['timestamp (SGT)'] = pd.to_datetime(r.json()['items'][0]['timestamp'].split('+')[0])
    carpark_df = carpark_df.append(temp_df, ignore_index=True)
carpark_df.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-211-43c3bc6d7e68> in <module>()
#       4     r = requests.get('https://api.data.gov.sg/v1/transport/carpark-availability',
#       5                      params={'date_time': dt.strftime('%Y-%m-%dT%H:%M:%S')})
# ----> 6     temp_df = pd.DataFrame(r.json()['items'][0]['carpark_data'])
#       7     #temp_df = temp_df.rename(columns={'lots_available': 'lots_available'})
#       8     temp_df['timestamp (SGT)'] = pd.to_datetime(r.json()['items'][0]['timestamp'].split('+')[0])
#
# IndexError: list index out of range

# %%
carpark_df.head()
# Out:
#                                         carpark_info carpark_number lot_type  \
# 0  [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12      NaN
# 1  [{'total_lots': '583', 'lot_type': 'C', 'lots_...            HLM      NaN
# 2  [{'total_lots': '329', 'lot_type': 'C', 'lots_...            RHM      NaN
# 3  [{'total_lots': '110', 'lot_type': 'C', 'lots_...           BM29      NaN
# 4  [{'total_lots': '97', 'lot_type': 'C', 'lots_a...            Q81      NaN
#
#   lots_available     timestamp (SGT) total_lots      update_datetime
# 0            NaN 2018-01-08 00:04:27        NaN  2018-01-08T00:03:19
# 1            NaN 2018-01-08 00:04:27        NaN  2018-01-08T00:03:12
# 2            NaN 2018-01-08 00:04:27        NaN  2018-01-08T00:03:07
# 3            NaN 2018-01-08 00:04:27        NaN  2017-08-01T12:15:17
# 4            NaN 2018-01-08 00:04:27        NaN  2018-01-08T00:03:27

# %%
#dt.strftime('%Y-%m-%dT%H:%M:%S')

# %%
#r.json()

# %%
#r.json()['items'][0]['carpark_data']

# %%
#temp_df = pd.DataFrame(r.json()['items'][0]['carpark_data'])

# %%
carpark_df['lots_available']=''

# %%
#type(carpark_df['carpark_info'][0])

# %%
#type(carpark_df['carpark_info'][0][0])

# %%
#carpark_df['carpark_info'][1][0]

# %%
len(carpark_df)
# Out:
# 73230

# %%
#carpark_df['lot_type']

# %%
carpark_df['carpark_info'][3][0]['lot_type']
# Out:
# 'C'

# %%
carpark_df['carpark_info'].head()
# Out:
# 0    [{'total_lots': '104', 'lot_type': 'C', 'lots_...
# 1    [{'total_lots': '583', 'lot_type': 'C', 'lots_...
# 2    [{'total_lots': '329', 'lot_type': 'C', 'lots_...
# 3    [{'total_lots': '110', 'lot_type': 'C', 'lots_...
# 4    [{'total_lots': '97', 'lot_type': 'C', 'lots_a...
# Name: carpark_info, dtype: object

# %%
type(carpark_df['carpark_info'][0][0])
# Out:
# dict

# %%
df3 = pd.DataFrame(carpark_df['carpark_info'].values.tolist(), columns=['carpark_info1','carpark_info2','carpark_info3'])
df3.head()
# Out:
#                                        carpark_info1 carpark_info2  \
# 0  {'total_lots': '104', 'lot_type': 'C', 'lots_a...          None
# 1  {'total_lots': '583', 'lot_type': 'C', 'lots_a...          None
# 2  {'total_lots': '329', 'lot_type': 'C', 'lots_a...          None
# 3  {'total_lots': '110', 'lot_type': 'C', 'lots_a...          None
# 4  {'total_lots': '97', 'lot_type': 'C', 'lots_av...          None
#
#   carpark_info3
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None

# %%
df3['carpark_info1'].head()
# Out:
# 0    {'total_lots': '104', 'lot_type': 'C', 'lots_a...
# 1    {'total_lots': '583', 'lot_type': 'C', 'lots_a...
# 2    {'total_lots': '329', 'lot_type': 'C', 'lots_a...
# 3    {'total_lots': '110', 'lot_type': 'C', 'lots_a...
# 4    {'total_lots': '97', 'lot_type': 'C', 'lots_av...
# Name: carpark_info1, dtype: object

# %%
type(df3['carpark_info1'][0])
# Out:
# dict

# %%
json.dumps(df3['carpark_info1'][0])
# Out:
# '{"total_lots": "104", "lot_type": "C", "lots_available": "39"}'

# %%
df3['carpark_info1'] = df3['carpark_info1'].apply(json.dumps)

# %%
type(df3['carpark_info1'][0])
# Out:
# str

# %%
#str(df3['carpark_info1'][0])

# %%
#df3['carpark_info1'].astype(str)

# %%
temp_df1, temp_df2, temp_df3 = df3['carpark_info1'].str.split(',').str

# %%
#temp_df3

# %%
#df3['carpark_info1'].head()
#temp_df1, temp_df2, temp_df3 = df3['carpark_info1'].astype(str).str.split(',').str

# %%
temp_df1.head()
# Out:
# 0    {"total_lots": "104"
# 1    {"total_lots": "583"
# 2    {"total_lots": "329"
# 3    {"total_lots": "110"
# 4     {"total_lots": "97"
# Name: carpark_info1, dtype: object

# %%
#str = "h3110 23 cat 444.4 rabbit 11 2 dog"
#[int(s) for s in str.split() if s.isdigit()]

# %%
temp_df1[0]
# Out:
# '{"total_lots": "104"'

# %%
str = temp_df1[0]
[int(s) for s in str.split('\"') if s.isdigit()]
# Out:
# [104]

# %% [markdown]
# ## Define function to extract number from string

# %%
def extract_number(x):
    str = x
    return [int(s) for s in str.split('\"') if s.isdigit()][0]

# %%
extract_number(temp_df1[0])
# Out:
# 104

# %%
# total lots
temp_df1.apply(extract_number).head()
# Out:
# 0    104
# 1    583
# 2    329
# 3    110
# 4     97
# Name: carpark_info1, dtype: int64

# %%
str = temp_df2[0]
[s for s in str.split('\"') if s.isalpha()]
# Out:
# ['C']

# %% [markdown]
# ## Define function to extract single character from string

# %%
def extract_alpha(x):
    str = x
    return [s for s in str.split('\"') if s.isalpha()][0]

# %%
extract_alpha(temp_df2[0])
# Out:
# 'C'

# %%
# lot type
temp_df2.apply(extract_alpha).head()
#temp_df2.head()
# Out:
# 0    C
# 1    C
# 2    C
# 3    C
# 4    C
# Name: carpark_info1, dtype: object

# %%
# lots available
temp_df3.apply(extract_number).head()
# Out:
# 0     39
# 1    473
# 2    102
# 3    109
# 4     72
# Name: carpark_info1, dtype: int64

# %%
#df3['carpark_info1'].head().str.split(',')

# %%
#temp_df1, temp_df2, temp_df3 = carpark_df['carpark_info'].str.split(',').str

# %%
#temp_df

# %% [markdown]
# ## Method below using 'for-loop', too slow

# %%
#for i in tqdm(range(0,len(carpark_df))):
#    carpark_df['lot_type'][i] = carpark_df['carpark_info'][i][0]['lot_type']
#    carpark_df['total_lots'][i] = carpark_df['carpark_info'][i][0]['total_lots']
#    carpark_df['lots_available'][i] = carpark_df['carpark_info'][i][0]['lots_available']

# %% [markdown]
# ## Vectorisation Method

# %%
carpark_df['lot_type'] = temp_df2.apply(extract_alpha)
carpark_df['total_lots'] = temp_df1.apply(extract_number)
carpark_df['lots_available'] = temp_df3.apply(extract_number)
carpark_df.head()
# Out:
#                                         carpark_info carpark_number lot_type  \
# 0  [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12        C
# 1  [{'total_lots': '583', 'lot_type': 'C', 'lots_...            HLM        C
# 2  [{'total_lots': '329', 'lot_type': 'C', 'lots_...            RHM        C
# 3  [{'total_lots': '110', 'lot_type': 'C', 'lots_...           BM29        C
# 4  [{'total_lots': '97', 'lot_type': 'C', 'lots_a...            Q81        C
#
#    lots_available     timestamp (SGT)  total_lots      update_datetime
# 0              39 2018-01-08 00:04:27         104  2018-01-08T00:03:19
# 1             473 2018-01-08 00:04:27         583  2018-01-08T00:03:12
# 2             102 2018-01-08 00:04:27         329  2018-01-08T00:03:07
# 3             109 2018-01-08 00:04:27         110  2017-08-01T12:15:17
# 4              72 2018-01-08 00:04:27          97  2018-01-08T00:03:27

# %%
outer_df = pd.merge(carpark_df, info_df, how='outer', on=['carpark_number'])
outer_df.head(15)
# Out:
#                                          carpark_info carpark_number lot_type  \
# 0   [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12        C
# 1   [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12        C
# 2   [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12        C
# 3   [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12        C
# 4   [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12        C
# 5   [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12        C
# 6   [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12        C
# 7   [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12        C
# 8   [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12        C
# 9   [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12        C
# 10  [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12        C
# 11  [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12        C
# 12  [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12        C
# 13  [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12        C
# 14  [{'total_lots': '104', 'lot_type': 'C', 'lots_...           HE12        C
#
#     lots_available     timestamp (SGT)  total_lots      update_datetime  \
# 0             62.0 2018-04-17 00:04:28       104.0  2018-04-17T00:03:23
# 1             59.0 2018-04-17 00:34:30       104.0  2018-04-17T00:33:23
# 2             59.0 2018-04-17 01:04:29       104.0  2018-04-17T01:03:23
# 3             59.0 2018-04-17 01:34:28       104.0  2018-04-17T01:33:23
# 4             58.0 2018-04-17 02:04:28       104.0  2018-04-17T02:03:23
# 5             57.0 2018-04-17 02:34:28       104.0  2018-04-17T02:33:23
# 6             57.0 2018-04-17 03:04:28       104.0  2018-04-17T03:03:32
# 7             59.0 2018-04-17 03:34:27       104.0  2018-04-17T03:33:32
# 8             74.0 2018-04-17 04:04:28       104.0  2018-04-17T04:03:32
# 9             74.0 2018-04-17 04:34:28       104.0  2018-04-17T04:33:32
# 10            74.0 2018-04-17 05:04:28       104.0  2018-04-17T05:03:32
# 11            69.0 2018-04-17 05:34:27       104.0  2018-04-17T05:33:32
# 12            72.0 2018-04-17 06:04:28       104.0  2018-04-17T06:03:32
# 13            71.0 2018-04-17 06:34:29       104.0  2018-04-17T06:33:33
# 14            65.0 2018-04-17 07:04:28       104.0  2018-04-17T07:03:33
#
#                    address     x_coord     y_coord     car_park_type  \
# 0   BLK 78/81 REDHILL LANE  26367.5806  30069.2434  SURFACE CAR PARK
# 1   BLK 78/81 REDHILL LANE  26367.5806  30069.2434  SURFACE CAR PARK
# 2   BLK 78/81 REDHILL LANE  26367.5806  30069.2434  SURFACE CAR PARK
# 3   BLK 78/81 REDHILL LANE  26367.5806  30069.2434  SURFACE CAR PARK
# 4   BLK 78/81 REDHILL LANE  26367.5806  30069.2434  SURFACE CAR PARK
# 5   BLK 78/81 REDHILL LANE  26367.5806  30069.2434  SURFACE CAR PARK
# 6   BLK 78/81 REDHILL LANE  26367.5806  30069.2434  SURFACE CAR PARK
# 7   BLK 78/81 REDHILL LANE  26367.5806  30069.2434  SURFACE CAR PARK
# 8   BLK 78/81 REDHILL LANE  26367.5806  30069.2434  SURFACE CAR PARK
# 9   BLK 78/81 REDHILL LANE  26367.5806  30069.2434  SURFACE CAR PARK
# 10  BLK 78/81 REDHILL LANE  26367.5806  30069.2434  SURFACE CAR PARK
# 11  BLK 78/81 REDHILL LANE  26367.5806  30069.2434  SURFACE CAR PARK
# 12  BLK 78/81 REDHILL LANE  26367.5806  30069.2434  SURFACE CAR PARK
# 13  BLK 78/81 REDHILL LANE  26367.5806  30069.2434  SURFACE CAR PARK
# 14  BLK 78/81 REDHILL LANE  26367.5806  30069.2434  SURFACE CAR PARK
#
#    type_of_parking_system short_term_parking             free_parking  \
# 0      ELECTRONIC PARKING          WHOLE DAY  SUN & PH FR 7AM-10.30PM
# 1      ELECTRONIC PARKING          WHOLE DAY  SUN & PH FR 7AM-10.30PM
# 2      ELECTRONIC PARKING          WHOLE DAY  SUN & PH FR 7AM-10.30PM
# 3      ELECTRONIC PARKING          WHOLE DAY  SUN & PH FR 7AM-10.30PM
# 4      ELECTRONIC PARKING          WHOLE DAY  SUN & PH FR 7AM-10.30PM
# 5      ELECTRONIC PARKING          WHOLE DAY  SUN & PH FR 7AM-10.30PM
# 6      ELECTRONIC PARKING          WHOLE DAY  SUN & PH FR 7AM-10.30PM
# 7      ELECTRONIC PARKING          WHOLE DAY  SUN & PH FR 7AM-10.30PM
# 8      ELECTRONIC PARKING          WHOLE DAY  SUN & PH FR 7AM-10.30PM
# 9      ELECTRONIC PARKING          WHOLE DAY  SUN & PH FR 7AM-10.30PM
# 10     ELECTRONIC PARKING          WHOLE DAY  SUN & PH FR 7AM-10.30PM
# 11     ELECTRONIC PARKING          WHOLE DAY  SUN & PH FR 7AM-10.30PM
# 12     ELECTRONIC PARKING          WHOLE DAY  SUN & PH FR 7AM-10.30PM
# 13     ELECTRONIC PARKING          WHOLE DAY  SUN & PH FR 7AM-10.30PM
# 14     ELECTRONIC PARKING          WHOLE DAY  SUN & PH FR 7AM-10.30PM
#
#    night_parking longitude latitude
# 0            YES   103.819  1.28821
# 1            YES   103.819  1.28821
# 2            YES   103.819  1.28821
# 3            YES   103.819  1.28821
# 4            YES   103.819  1.28821
# 5            YES   103.819  1.28821
# 6            YES   103.819  1.28821
# 7            YES   103.819  1.28821
# 8            YES   103.819  1.28821
# 9            YES   103.819  1.28821
# 10           YES   103.819  1.28821
# 11           YES   103.819  1.28821
# 12           YES   103.819  1.28821
# 13           YES   103.819  1.28821
# 14           YES   103.819  1.28821

# %%
#r = requests.get('https://developers.onemap.sg/commonapi/convert/3414to4326?X={}&Y={}'.format(variable))

# %%
r = requests.get('https://developers.onemap.sg/commonapi/convert/3414to4326?X=28983.788791079794&Y=33554.5098132845')
r.json()
# Out:
# {'latitude': 1.3197295716669164, 'longitude': 103.84215843333567}

# %%
r = requests.get('https://developers.onemap.sg/commonapi/convert/3414to4326',
                     params={'X': '28983.788791079794', 'Y': '33554.5098132845'})
r.json()
# Out:
# {'latitude': 1.3197295716669164, 'longitude': 103.84215843333567}

# %%
filename = 'carpark_{}.csv'.format(date)
filename

outer_df.to_csv(filename, index = False)

# %%
carpark_df['lot_type'][0]
# Out:
# 'C'

# %%
carpark_df.head()

# %%
outer_df.describe()
# Out:
#        lots_available    total_lots       x_coord       y_coord
# count    73230.000000  73230.000000  71075.000000  71075.000000
# mean       197.334467    400.487054  28775.066967  37777.370982
# std        197.524002    323.881305   7956.053479   4802.618377
# min          0.000000      2.000000  11539.089800  28123.411600
# 25%         51.000000    180.000000  22252.486000  34382.230500
# 50%        149.000000    337.000000  29482.029000  37234.277300
# 75%        286.000000    530.000000  35011.040100  40693.989700
# max       1999.000000   4443.000000  45264.580600  48691.430800

# %%
len(temp_df)
# Out:
# 1668

# %%
#temp_df[['total_lots','lot_type','lots_available']] = pd.DataFrame(temp_df.carpark_info.values.tolist(), index= temp_df.index)
